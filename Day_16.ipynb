# %% [markdown]
# <a href="https://colab.research.google.com/github/AaryanBairagi/GeekForGeeks-21Days-21Projects-Challenge/blob/main/Day_16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **IMPORT DATASET**

# %%
import kagglehub

path = kagglehub.dataset_download("urbikn/sroie-datasetv2")

print("Path to Dataset files : ", path)
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/urbikn/sroie-datasetv2?dataset_version_number=4...
# 100%|██████████| 834M/834M [00:09<00:00, 94.7MB/s]
# Extracting files...
# Path to Dataset files :  /root/.cache/kagglehub/datasets/urbikn/sroie-datasetv2/versions/4

# %%
# !pip install opencv-python matplotlib numpy
# Out:
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.12/dist-packages (4.12.0.88)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.60.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.2.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
import os

one_image_path = os.path.join(path, 'SROIE2019' , 'train' , 'img' , 'X51005453729.jpg')

# %%
import matplotlib.pyplot as plt
import cv2
def display_image(image,title="Image"):
  plt.figure(figsize=(7,7))
  plt.imshow(cv2.cvtColor(image,cv2.COLOR_BGR2RGB))
  plt.title(title)
  plt.axis('off')
  plt.show()

# %%
one_image = cv2.imread(one_image_path)
display_image(one_image,"Original Receipt Image")

# %%
def convert2GrayScale(image):
  return cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)

# %%
grayscale_image = convert2GrayScale(one_image)
display_image(grayscale_image,"Gray Scale Image")

# %%
def reduce_noise(image):
  return cv2.GaussianBlur(image,(5,5),0)

# %%
blurred_image = reduce_noise(grayscale_image)
display_image(blurred_image,"Blur Reduced Image")

# %%
def binarize_image(blur_image):
  return cv2.adaptiveThreshold(blur_image ,
                               255 ,
                               cv2.ADAPTIVE_THRESH_GAUSSIAN_C ,
                               cv2.THRESH_BINARY_INV , 11 , 4)

# %%
binarized_image = binarize_image(blurred_image)
display_image(binarized_image,"Inverted Image")

# %%
def deskew_image(image):
  """
  Corrects the skew of an image by finding the minimum area rectangle
  of the text block and rotating accordingly.
  """

  coords = cv2.findNonZero(image)
  rect = cv2.minAreaRect(coords)
  angle = rect[-1] - 90

  if angle < -45 :
    angle = -(90 + angle)
  else :
    angle = -angle

  (h,w) = image.shape[:2]
  center = (w//2 , h//2)

  M = cv2.getRotationMatrix2D(center,angle,1.0)
  rotated = cv2.warpAffine(image,M,(w,h),flags=cv2.INTER_CUBIC,borderMode=cv2.BORDER_REPLICATE)
  print(f"Detected Skew Angle : {angle:.2f} degrees")

  (h,w) = rotated.shape
  center = (w//2,h//2)
  M = cv2.getRotationMatrix2D(center,angle,1.0)
  deskewed_gray = cv2.warpAffine(rotated,M,(w,h),flags=cv2.INTER_CUBIC,borderMode=cv2.BORDER_REPLICATE)

  return deskewed_gray

# %%
deskewed_image = deskew_image(binarized_image)
# Out:
# Detected Skew Angle : 2.91 degrees

# %%
display_image(deskewed_image,"Deskewed Image")

# %%
def process_one_image(image):
  image = convert2GrayScale(image)
  print("Converted Image to Gray Scale")
  image = reduce_noise(image)
  print("Reduced Noise")
  image = binarize_image(image)
  print("Binarized Image")
  image = deskew_image(image)
  print("Deskewed Image")
  return image

# %% [markdown]
# # **PROCESS IMAGE**

# %%
import time
output_folder_path = "/content/processed_images"
start_time = time.time()

os.makedirs(output_folder_path, exist_ok=True)
print(f"Created Folder : {output_folder_path}")

for image_name in os.listdir(os.path.join(path,'SROIE2019','train','img'))[:20]:
  print(f"Processing image : {image_name}")

  image_path = os.path.join(path,'SROIE2019','train','img',image_name)

  image = cv2.imread(image_path)

  processed_image = process_one_image(image)

  output_image_path = os.path.join(output_folder_path,image_name)
  cv2.imwrite(output_image_path,processed_image)
  print(f"Saved processed image to : {output_image_path}")
  print("-"*50)

  print(f"Processing Images is completed.")
  print(f"Total time taken : {time.time() - start_time} seconds")
# Out:
# Created Folder : /content/processed_images
# Processing image : X51005568891.jpg
# Converted Image to Gray Scale
# Reduced Noise
# Binarized Image
# Detected Skew Angle : -0.00 degrees
# Deskewed Image
# Saved processed image to : /content/processed_images/X51005568891.jpg
# --------------------------------------------------
# Processing Images is completed.
# Total time taken : 0.13624191284179688 seconds
# Processing image : X51005361897.jpg
# Converted Image to Gray Scale
# Reduced Noise
# Binarized Image
# Detected Skew Angle : -0.00 degrees
# Deskewed Image
# Saved processed image to : /content/processed_images/X51005361897.jpg
# --------------------------------------------------
# Processing Images is completed.
# Total time taken : 0.5864052772521973 seconds
# Processing image : X51007846412.jpg
# Converted Image to Gray Scale
# Reduced Noise
# Binarized Image
# Detected Skew Angle : 1.60 degrees
# Deskewed Image
# Saved processed image to : /content/processed_images/X51007846412.jpg
# --------------------------------------------------
# Processing Images is completed.
# Total time taken : 2.334716558456421 seconds
# Processing image : X51006556838.jpg
# Converted Image to Gray Scale
# Reduced Noise
# Binarized Image
# Detected Skew Angle : -0.00 degrees
# Deskewed Image
# Saved processed image to : /content/processed_images/X51006556838.jpg
# --------------------------------------------------
# Processing Images is completed.
# Total time taken : 2.383561849594116 seconds
# Processing image : X51005719856.jpg
# Converted Image to Gray Scale
# Reduced Noise
# Binarized Image
# Detected Skew Angle : -0.00 degrees
# Deskewed Image
# Saved processed image to : /content/processed_images/X51005719856.jpg
# --------------------------------------------------
# Processing Images is completed.
# Total time taken : 2.5061426162719727 seconds
# Processing image : X51007103578.jpg
# Converted Image to Gray Scale
# Reduced Noise
# Binarized Image
# Detected Skew Angle : 0.03 degrees
# Deskewed Image
# Saved processed image to : /content/processed_images/X51007103578.jpg
# --------------------------------------------------
# Processing Images is completed.
# Total time taken : 2.5847299098968506 seconds
# Processing image : X51007846325.jpg
# Converted Image to Gray Scale
# Reduced Noise
# Binarized Image
# Detected Skew Angle : 1.82 degrees
# Deskewed Image
# Saved processed image to : /content/processed_images/X51007846325.jpg
# --------------------------------------------------
# Processing Images is completed.
# Total time taken : 4.307939529418945 seconds
# Processing image : X51008123586.jpg
# Converted Image to Gray Scale
# Reduced Noise
# Binarized Image
# Detected Skew Angle : -0.00 degrees
# Deskewed Image
# Saved processed image to : /content/processed_images/X51008123586.jpg
# --------------------------------------------------
# Processing Images is completed.
# Total time taken : 4.348267316818237 seconds
# Processing image : X51006557188.jpg
# Converted Image to Gray Scale
# Reduced Noise
# Binarized Image
# Detected Skew Angle : -0.00 degrees
# Deskewed Image
# Saved processed image to : /content/processed_images/X51006557188.jpg
# --------------------------------------------------
# Processing Images is completed.
# Total time taken : 4.3970794677734375 seconds
# Processing image : X51008099049.jpg
# Converted Image to Gray Scale
# Reduced Noise
# Binarized Image
# Detected Skew Angle : -0.00 degrees
# Deskewed Image
# Saved processed image to : /content/processed_images/X51008099049.jpg
# --------------------------------------------------
# Processing Images is completed.
# Total time taken : 4.501720666885376 seconds
# Processing image : X51006619496.jpg
# Converted Image to Gray Scale
# Reduced Noise
# Binarized Image
# Detected Skew Angle : -0.00 degrees
# Deskewed Image
# Saved processed image to : /content/processed_images/X51006619496.jpg
# --------------------------------------------------
# Processing Images is completed.
# Total time taken : 4.614175081253052 seconds
# Processing image : X51007231338.jpg
# Converted Image to Gray Scale
# Reduced Noise
# Binarized Image
# Detected Skew Angle : -0.26 degrees
# Deskewed Image
# Saved processed image to : /content/processed_images/X51007231338.jpg
# --------------------------------------------------
# Processing Images is completed.
# Total time taken : 6.354525327682495 seconds
# Processing image : X51005447861.jpg
# Converted Image to Gray Scale
# Reduced Noise
# Binarized Image
# Detected Skew Angle : -0.00 degrees
# Deskewed Image
# Saved processed image to : /content/processed_images/X51005447861.jpg
# --------------------------------------------------
# Processing Images is completed.
# Total time taken : 6.586474895477295 seconds
# Processing image : X51005676541.jpg
# Converted Image to Gray Scale
# Reduced Noise
# Binarized Image
# Detected Skew Angle : -0.00 degrees
# Deskewed Image
# Saved processed image to : /content/processed_images/X51005676541.jpg
# --------------------------------------------------
# Processing Images is completed.
# Total time taken : 6.773745536804199 seconds
# Processing image : X51006414519.jpg
# Converted Image to Gray Scale
# Reduced Noise
# Binarized Image
# Detected Skew Angle : 0.52 degrees
# Deskewed Image
# Saved processed image to : /content/processed_images/X51006414519.jpg
# --------------------------------------------------
# Processing Images is completed.
# Total time taken : 9.182876110076904 seconds
# Processing image : X51007339132.jpg
# Converted Image to Gray Scale
# Reduced Noise
# Binarized Image
# Detected Skew Angle : -0.00 degrees
# Deskewed Image
# Saved processed image to : /content/processed_images/X51007339132.jpg
# --------------------------------------------------
# Processing Images is completed.
# Total time taken : 9.238335609436035 seconds
# Processing image : X51006557178.jpg
# Converted Image to Gray Scale
# Reduced Noise
# Binarized Image
# Detected Skew Angle : -0.00 degrees
# Deskewed Image
# Saved processed image to : /content/processed_images/X51006557178.jpg
# --------------------------------------------------
# Processing Images is completed.
# Total time taken : 9.285773038864136 seconds
# Processing image : X51008063849.jpg
# Converted Image to Gray Scale
# Reduced Noise
# Binarized Image
# Detected Skew Angle : -0.26 degrees
# Deskewed Image
# Saved processed image to : /content/processed_images/X51008063849.jpg
# --------------------------------------------------
# Processing Images is completed.
# Total time taken : 9.34254002571106 seconds
# Processing image : X51006619862.jpg
# Converted Image to Gray Scale
# Reduced Noise
# Binarized Image
# Detected Skew Angle : -0.00 degrees
# Deskewed Image
# Saved processed image to : /content/processed_images/X51006619862.jpg
# --------------------------------------------------
# Processing Images is completed.
# Total time taken : 9.427194595336914 seconds
# Processing image : X51005757323.jpg
# Converted Image to Gray Scale
# Reduced Noise
# Binarized Image
# Detected Skew Angle : -0.04 degrees
# Deskewed Image
# Saved processed image to : /content/processed_images/X51005757323.jpg
# --------------------------------------------------
# Processing Images is completed.
# Total time taken : 9.492392778396606 seconds

# %% [markdown]
# # **TEXT EXTRACTION**

# %%
! pip install pytesseract pillow
# Out:
# Collecting pytesseract
#   Downloading pytesseract-0.3.13-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (11.3.0)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.12/dist-packages (from pytesseract) (25.0)
# Downloading pytesseract-0.3.13-py3-none-any.whl (14 kB)
# Installing collected packages: pytesseract
# Successfully installed pytesseract-0.3.13

# %%
from PIL import Image
import pytesseract

# %%
pytesseract.image_to_string(Image.open('/content/processed_images/X51006619496.jpg'))
# Out:
# "Cea that a alae oh Oi he adh Pe eee)\n\nP J\n\n30 ACS Le iat\nPOMC BGs re\ncet meek\n41150 KLANG, SELANGOR °\nRY eat mu!\n\nGST 1D. NOs GOOL81747712\n\nsO CS OCA\n\nOs S107 ai Coo Vs ane\nCY 7 aS cs SR\n‘155 TWISTIES CHIPSTER ORIG © RH2,85's\nmS C0\n\n \n\noye au |\neee eRe\n20 re\nacts Cet a aes\n507 CORE L.SL eee\nPee Owe)\n\nSe eet ee Cyc\nTotal Sales (Inclusive GST) RH 61.65\n\naN CM\n\nCHANGE RH* <0\nSS UEC\nst bh aw) a\na a 24.95. OO\n\nThank You. Please cone again\nKeep the invoice for applicable a\n\nae\n\nSree reer re\n\n \n\x0c"

# %%
from PIL import Image
import pytesseract
import time
import os

input_folder_path = "/content/processed_images"
output_folder_path = "/content/tesseract_output"
start_time = time.time()

os.makedirs(output_folder_path , exist_ok=True)
print(f"Created Folder : {output_folder_path}")

total_images = sum(1 for entry in os.scandir(input_folder_path))
print(f"Total Images in Folder : {total_images}")

for i , image_name in enumerate(os.listdir(input_folder_path)[:20],1):
  print(f"Processing image {i}/{total_images}: {image_name}")
  image_path = os.path.join(input_folder_path, image_name)
  print("Extracting text from image..")
  text = pytesseract.image_to_string(Image.open(image_path))
  output_path = os.path.join(output_folder_path, image_name.replace(".jpg", ".txt"))
  with open(output_path, "w") as f:
    f.write(text)

  print(f"Saved extracted text to {output_path}")
  print("-"*50)

print("Text Extraction Completed.")
print(f"Total time taken: {time.time() - start_time} seconds")
# Out:
# Created Folder : /content/tesseract_output
# Total Images in Folder : 20
# Processing image 1/20: X51005568891.jpg
# Extracting text from image..
# Saved extracted text to /content/tesseract_output/X51005568891.txt
# --------------------------------------------------
# Processing image 2/20: X51005361897.jpg
# Extracting text from image..
# Saved extracted text to /content/tesseract_output/X51005361897.txt
# --------------------------------------------------
# Processing image 3/20: X51007846412.jpg
# Extracting text from image..
# Saved extracted text to /content/tesseract_output/X51007846412.txt
# --------------------------------------------------
# Processing image 4/20: X51006556838.jpg
# Extracting text from image..
# Saved extracted text to /content/tesseract_output/X51006556838.txt
# --------------------------------------------------
# Processing image 5/20: X51005719856.jpg
# Extracting text from image..
# Saved extracted text to /content/tesseract_output/X51005719856.txt
# --------------------------------------------------
# Processing image 6/20: X51007103578.jpg
# Extracting text from image..
# Saved extracted text to /content/tesseract_output/X51007103578.txt
# --------------------------------------------------
# Processing image 7/20: X51007846325.jpg
# Extracting text from image..
# Saved extracted text to /content/tesseract_output/X51007846325.txt
# --------------------------------------------------
# Processing image 8/20: X51008123586.jpg
# Extracting text from image..
# Saved extracted text to /content/tesseract_output/X51008123586.txt
# --------------------------------------------------
# Processing image 9/20: X51006557188.jpg
# Extracting text from image..
# Saved extracted text to /content/tesseract_output/X51006557188.txt
# --------------------------------------------------
# Processing image 10/20: X51008099049.jpg
# Extracting text from image..
# Saved extracted text to /content/tesseract_output/X51008099049.txt
# --------------------------------------------------
# Processing image 11/20: X51006619496.jpg
# Extracting text from image..
# Saved extracted text to /content/tesseract_output/X51006619496.txt
# --------------------------------------------------
# Processing image 12/20: X51007231338.jpg
# Extracting text from image..
# Saved extracted text to /content/tesseract_output/X51007231338.txt
# --------------------------------------------------
# Processing image 13/20: X51005447861.jpg
# Extracting text from image..
# Saved extracted text to /content/tesseract_output/X51005447861.txt
# --------------------------------------------------
# Processing image 14/20: X51005676541.jpg
# Extracting text from image..
# Saved extracted text to /content/tesseract_output/X51005676541.txt
# --------------------------------------------------
# Processing image 15/20: X51006414519.jpg
# Extracting text from image..
# Saved extracted text to /content/tesseract_output/X51006414519.txt
# --------------------------------------------------
# Processing image 16/20: X51007339132.jpg
# Extracting text from image..
# Saved extracted text to /content/tesseract_output/X51007339132.txt
# --------------------------------------------------
# Processing image 17/20: X51006557178.jpg
# Extracting text from image..
# Saved extracted text to /content/tesseract_output/X51006557178.txt
# --------------------------------------------------
# Processing image 18/20: X51008063849.jpg
# Extracting text from image..
# Saved extracted text to /content/tesseract_output/X51008063849.txt
# --------------------------------------------------
# Processing image 19/20: X51006619862.jpg
# Extracting text from image..
# Saved extracted text to /content/tesseract_output/X51006619862.txt
# --------------------------------------------------
# Processing image 20/20: X51005757323.jpg
# Extracting text from image..
# Saved extracted text to /content/tesseract_output/X51005757323.txt
# --------------------------------------------------
# Text Extraction Completed.
# Total time taken: 101.53263759613037 seconds

# %% [markdown]
# # **INFORMATION EXTRACTION**

# %%
prompt = """
Extract the information from the given image.
Information to be extracted: company, date, address, total.
The image has been converted to grayscale, noise reduced, binarized, and deskewed using opencv.
Always give your response in the following format:
{
    "company": "COMPANY_NAME",
    "date": "DATE",
    "address": "ADDRESS",
    "total": "TOTAL",
}
Also, the text has been extracted from the image using tesseract.
Use the extracted text as support for extracting information.
If you believe the extraction is incorrect somewhere, you may correct it yourself and provide corrected information.
Respond with the extracted information only in the specified format.
Here is the text:


"""

# %%
from google import genai
from PIL import Image
from google.colab import userdata
import json
import time

# %%
genai_client = genai.Client(api_key=userdata.get("smart_IDP"))

# %%
image_folder_path = '/content/processed_images'
text_folder_path = '/content/tesseract_output'
output_folder_path = '/content/json_output'

start_time = time.time()

os.makedirs(output_folder_path,exist_ok=True)
print(f"Created Folder : {output_folder_path}")

total_images = sum(1 for entry in os.scandir(image_folder_path))
print(f"Total images in folder : {total_images}")

for i , image_name in enumerate(os.listdir(image_folder_path)[:20],1):
  image_path = os.path.join(image_folder_path , image_name)
  with open(image_path,"rb") as f:
    image = Image.open(image_path)

  text_path = os.path.join(text_folder_path , image_name.replace(".jpg",".txt"))
  with open(text_path , "r") as f:
    text = f.read()

  prompt = prompt + text

  contents = [ image , {"text" : prompt} ]

  response = genai_client.models.generate_content(model='gemini-2.5-flash',contents=contents)

  usage_metadata = response.usage_metadata
  print(f"Input Token Count: {usage_metadata.prompt_token_count}")
  print(f"Thoughts Token Count: {response.usage_metadata.thoughts_token_count}")
  print(f"Output Token Count: {usage_metadata.candidates_token_count}")
  print(f"Total Token Count: {usage_metadata.total_token_count}")

  extracted_information = json.loads(response.text.replace('```json','').replace('```',''))
  print(extracted_information)

  output_path = os.path.join(output_folder_path , image_name.replace(".jpg",".json"))
  with open(output_path,"w") as f:
    json.dump(extracted_information, f, indent=4)

  time.sleep(60)
  print("Information Extraction Completed")
  print(f"Time Taken : {time.time() - start_time} seconds")
# Out:
# Created Folder : /content/json_output
# Total images in folder : 20
# Input Token Count: 1485
# Thoughts Token Count: 319
# Output Token Count: 90
# Total Token Count: 1894
# {'company': 'HON HWA HARDWARE TRADING', 'date': '08/02/2017', 'address': 'NO 37, JALAN MANIS 7, TAMAN SEGAR, 56100 CHERAS, KUALA LUMPUR.', 'total': '277.00'}
# Information Extraction Completed
# Time Taken : 64.26266384124756 seconds
# Input Token Count: 1772
# Thoughts Token Count: 1099
# Output Token Count: 90
# Total Token Count: 2961
# {'company': 'TEO HENG STATIONERY & BOOKS', 'date': '17/01/2018', 'address': 'NO. 53, JALAN BESAR, 45600 BATANG KALI, SELANGOR DARUL EHSAN', 'total': '27.55'}
# Information Extraction Completed
# Time Taken : 133.8345491886139 seconds
# Input Token Count: 2171
# Thoughts Token Count: 737
# Output Token Count: 114
# Total Token Count: 3022
# {'company': 'LAVENDER CONFECTIONERY & BAKERY S/B', 'date': '17/08/2018', 'address': 'LOT G29 & G30, AEON Mall TEBRAU CITY, NO. 1, JALAN DESA TEBRAU, TAMAN DESA TEBRAU, 81100 JOHOR BAHRU.', 'total': '26.50'}
# Information Extraction Completed
# Time Taken : 203.44919610023499 seconds
# Input Token Count: 2629
# Thoughts Token Count: 432
# Output Token Count: 88
# Total Token Count: 3149
# {'company': 'GARDENIA BAKERIES (KL) SDN BHD', 'date': '19/09/2017', 'address': 'Lot 3, Jalan Pelabur 23/1, 40300 Shah Alam, Selangor.', 'total': '22.58'}
# Information Extraction Completed
# Time Taken : 268.4417359828949 seconds
# Input Token Count: 2959
# Thoughts Token Count: 268
# Output Token Count: 104
# Total Token Count: 3331
# {'company': 'BASKIN BR ROBBINS', 'date': '16/02/2018', 'address': 'Desa Park City Golden Scoop Sdn Bhd (169609-A) A-16-1, Tower A, Northpoint Office, Mid Valley City, No1, Medan Syed Putra Utara Kuala Lumpur Malaysia', 'total': '21.50'}
# Information Extraction Completed
# Time Taken : 332.9492964744568 seconds
# Input Token Count: 3425
# Thoughts Token Count: 206
# Output Token Count: 116
# Total Token Count: 3747
# {'company': 'MR. D.I.Y. (M) SDN BHD', 'date': '06-04-18', 'address': 'LOT 1851-A & 1851-B, JALAN FPB 6, KAWASAN PERINDUSTRIAN BALAKONG, 43300 SERI KEMBANGAN, SELANGOR', 'total': '31.20'}
# Information Extraction Completed
# Time Taken : 396.58648586273193 seconds
# Input Token Count: 3725
# Thoughts Token Count: 301
# Output Token Count: 87
# Total Token Count: 4113
# {'company': 'DE LUXE FRESH MART SDN BHD', 'date': '02/06/18', 'address': 'No. 89&91, Jalan Utama, Taman Mutiara Rini, 81300 Skudai, Johor.', 'total': '25.85'}
# Information Extraction Completed
# Time Taken : 462.1244785785675 seconds
# Input Token Count: 4060
# Thoughts Token Count: 224
# Output Token Count: 110
# Total Token Count: 4394
# {'company': 'myNEWS.com', 'date': '29/06/2018', 'address': 'LOUNGE 2, GROUND FLOOR, OASIS VILLAGE,NO 2, JALAN PJU 1A/7A, OASIS SQUARE,OASIS DAMANSARA, 47301, PETALING JAYA, SELANGOR', 'total': '7.70'}
# Information Extraction Completed
# Time Taken : 525.7310388088226 seconds
# Input Token Count: 4461
# Thoughts Token Count: 455
# Output Token Count: 88
# Total Token Count: 5004
# {'company': 'GARDENIA BAKERIES (KL) SDN BHD', 'date': '15/10/2017', 'address': 'Lot 3, Jalan Pelabur 23/1, 40300 Shah Alam, Selangor.', 'total': '23.56'}
# Information Extraction Completed
# Time Taken : 590.5853450298309 seconds
# Input Token Count: 4783
# Thoughts Token Count: 356
# Output Token Count: 106
# Total Token Count: 5245
# {'company': 'PappaRich BMC', 'date': '15/06/2018', 'address': 'NO.19 & 21\nJALAN TEMENGGUNG 23/9\nBANDAR MAHKOTA CHERAS\n43200 SELANGOR DARUL EHSAN, MALAYSIA', 'total': '17.20'}
# Information Extraction Completed
# Time Taken : 655.1152186393738 seconds
# Input Token Count: 5011
# Thoughts Token Count: 510
# Output Token Count: 104
# Total Token Count: 5625
# {'company': '99 SPEED MART S/B', 'date': '14-12-2016', 'address': 'LOT P.T. 2811, JALAN ANGSA, TAMAN BERKELEY, 41150 KLANG, SELANGOR, 1320-THN BATU', 'total': '61.65'}
# Information Extraction Completed
# Time Taken : 720.958174943924 seconds
# Input Token Count: 5403
# Thoughts Token Count: 368
# Output Token Count: 85
# Total Token Count: 5856
# {'company': 'AMPHAWA THAI TEA & CO.', 'date': '11/06/2018', 'address': 'PARADIGM MALL, LOT NO.: 4F-27 & 4EK-38, 4TH FLOOR', 'total': '9.45'}
# Information Extraction Completed
# Time Taken : 787.7535042762756 seconds
# Input Token Count: 5703
# Thoughts Token Count: 607
# Output Token Count: 91
# Total Token Count: 6401
# {'company': 'POPULAR BOOK CO. (M) SDN BHD', 'date': '01/03/18', 'address': 'No 8, Jalan 7/118B, Desa Tun Razak 56000 Kuala Lumpur, Malaysia SUNWAY VELOCITY', 'total': '49.39'}
# Information Extraction Completed
# Time Taken : 855.1583619117737 seconds
# Input Token Count: 6107
# Thoughts Token Count: 294
# Output Token Count: 90
# Total Token Count: 6491
# {'company': 'SYARIKAT PERNIAGAAN GIN KEE', 'date': '03/01/2018', 'address': 'NO 290, JALAN AIR PANAS, SETAPAK, 53200, KUALA LUMPUR.', 'total': '94.87'}
# Information Extraction Completed
# Time Taken : 919.1624979972839 seconds
# Input Token Count: 6353
# Thoughts Token Count: 1028
# Output Token Count: 81
# Total Token Count: 7462
# {'company': 'HASHA PETROKIOSK', 'date': '2018-04-06', 'address': 'Lot PTD 198718 Tmn Sierra P\n81750 Masai Johor', 'total': '50.00'}
# Information Extraction Completed
# Time Taken : 988.6093196868896 seconds
# Input Token Count: 6665
# Thoughts Token Count: 403
# Output Token Count: 92
# Total Token Count: 7160
# {'company': 'SANYU STATIONERY SHOP', 'date': '06/09/2017', 'address': 'NO. 31G&33G; JALAN SETIA INDAH X ;U13/X\n40170 SETIA ALAM', 'total': '8.70'}
# Information Extraction Completed
# Time Taken : 1054.0904321670532 seconds
# Input Token Count: 7064
# Thoughts Token Count: 871
# Output Token Count: 88
# Total Token Count: 8023
# {'company': 'GARDENIA BAKERIES (KL) SDN BHD', 'date': '25/10/2017', 'address': 'Lot 3, Jalan Pelabur 23/1, 40300 Shah Alam, Selangor.', 'total': '35.01'}
# Information Extraction Completed
# Time Taken : 1121.127259016037 seconds
# Input Token Count: 7323
# Thoughts Token Count: 176
# Output Token Count: 115
# Total Token Count: 7614
# {'company': 'MR. D.I.Y. (M) SDN BHD', 'date': '28-05-18', 'address': 'LOT 1851-A & 1851-B, JALAN KPB 6, KAWASAN PERINDUSTRIAN BALAKONG, 43300 SERI KEMBANGAN, SELANGOR', 'total': '2.70'}
# Information Extraction Completed
# Time Taken : 1184.26149392128 seconds
# Input Token Count: 7604
# Thoughts Token Count: 1145
# Output Token Count: 118
# Total Token Count: 8867
# {'company': 'MR. D.I.Y. (KUCHAI) SDN BHD', 'date': '07-03-16', 'address': 'LOT 1851-A & 1851-B, JALAN KPB 6, KAWASAN PERINDUSTRIAN BALAKONG, 43300 SERI KEMBANGAN, SELANGOR', 'total': '13.30'}
# Information Extraction Completed
# Time Taken : 1253.837891817093 seconds
# Input Token Count: 7971
# Thoughts Token Count: 473
# Output Token Count: 116
# Total Token Count: 8560
# {'company': 'MR. D.I.Y. (M) SDN BHD', 'date': '26-03-18', 'address': 'LOT 1851-A & 1851-B, JALAN KPB 6, KAWASAN PERINDUSTRIAN BALAKONG, 43300 SERI KEMBANGAN, SELANGOR', 'total': '28.00'}
# Information Extraction Completed
# Time Taken : 1319.580573797226 seconds

# %% [markdown]
# # **SUBMISSION TASK**

# %%
import kagglehub

path_new = kagglehub.dataset_download('snehaanbhawal/resume-dataset')

print("Path to Dataset files : ", path_new)
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/snehaanbhawal/resume-dataset?dataset_version_number=1...
# 100%|██████████| 62.5M/62.5M [00:00<00:00, 149MB/s]
# Extracting files...
# Path to Dataset files :  /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1

# %%
# !pip install pdf2image
# Out:
# Collecting pdf2image
#   Downloading pdf2image-1.17.0-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from pdf2image) (11.3.0)
# Downloading pdf2image-1.17.0-py3-none-any.whl (11 kB)
# Installing collected packages: pdf2image
# Successfully installed pdf2image-1.17.0

# %%
# Install Poppler
# !apt-get install -y poppler-utils
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   poppler-utils
# 0 upgraded, 1 newly installed, 0 to remove and 38 not upgraded.
# Need to get 186 kB of archives.
# After this operation, 697 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 poppler-utils amd64 22.02.0-2ubuntu0.10 [186 kB]
# Fetched 186 kB in 1s (363 kB/s)
# Selecting previously unselected package poppler-utils.
# (Reading database ... 126441 files and directories currently installed.)
# Preparing to unpack .../poppler-utils_22.02.0-2ubuntu0.10_amd64.deb ...
# Unpacking poppler-utils (22.02.0-2ubuntu0.10) ...
# Setting up poppler-utils (22.02.0-2ubuntu0.10) ...
# Processing triggers for man-db (2.10.2-1) ...

# %%
import os

for root, dirs, files in os.walk(path_new):
    for file in files:
        if file.endswith('.pdf'):
            print(os.path.join(root, file))
# Out:
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/96457008.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/99416532.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/69458502.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/31605080.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/37473139.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/17876954.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/81588968.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/29534737.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/15823995.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/22232367.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/24154692.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/12239749.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/23464505.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/17655479.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/20026169.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/12504278.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/15684810.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/54232810.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/28383893.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/31536294.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/15618327.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/90318913.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/19506295.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/19818707.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/29221006.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/61315605.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/22168194.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/18268860.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/23761385.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/30148777.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/82738323.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/16279537.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/17008356.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/42641525.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/16833515.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/25625173.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/24668861.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/12192507.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/38355831.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/11804712.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/11137306.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/13195436.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/29167286.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/25718772.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/17694572.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/14589288.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/49646155.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/67631413.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/68216398.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/11959428.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/21287405.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/43408471.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/27502951.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/26888302.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/10189110.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/22650051.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/17686472.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/94137171.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/34419403.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/92283635.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/33627938.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/58048626.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/12043694.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/22990761.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/26279402.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/24773845.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/10945968.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/36252245.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/28186635.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/22442947.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/14874322.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/17483843.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/25719936.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/13405229.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/10567764.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/50775901.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/11614114.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/17152392.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/27512470.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/21190805.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/10395944.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/32720816.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/13234267.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/29595906.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/38154903.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/91431878.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/98389424.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/16850314.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/23985183.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/28020046.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/12144825.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/36727173.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/11752500.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/24589765.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/42546558.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/77626587.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/38989376.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/17274759.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/11169163.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/87826037.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/38663892.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/42427521.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/65219288.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/11333001.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/16449694.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/10176815.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/14790629.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/24544244.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/12904972.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/70198580.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/19284293.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/43720116.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/29161565.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/27902692.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/26819872.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/17983430.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AVIATION/38047274.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/26746496.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/26801767.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/16899268.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/68460556.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/20674668.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/13405733.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/51363762.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/79541391.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/13385306.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/17987433.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/25959103.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/28897981.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/52246737.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/20237244.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/30223363.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/52618188.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/20879311.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/23666211.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/91121135.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/17111768.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/66832845.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/12045067.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/11957080.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/13836471.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/18067556.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/28672970.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/10839851.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/36434348.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/10247517.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/12763627.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/23864648.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/26480367.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/25207620.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/22450718.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/27295996.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/28697203.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/18176523.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/12334140.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/91697974.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/24083609.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/31243710.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/91635250.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/48037995.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/27770859.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/21780877.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/23527321.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/10265057.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/18752129.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/24230851.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/35325329.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/10641230.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/17681064.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/18159866.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/18301617.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/37242217.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/33381211.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/38753827.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/27058381.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/17641670.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/33241454.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/57002858.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/20408458.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/70089206.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/36856210.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/39718499.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/20024870.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/21283365.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/26768723.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/51639418.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/25905275.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/24038620.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/11584809.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/24020470.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/31111279.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/19850482.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/15802627.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/11580408.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/64017585.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/92069209.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/83816738.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/81761658.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/28126340.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/18187364.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/15651486.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/27372171.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/29975124.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/22776912.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/20001721.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/15791766.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/24913648.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/41344156.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/25857360.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/10840430.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/89413122.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/16186411.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/90867631.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/20824105.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/10089434.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/12635195.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/19201175.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/10553553.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/29051656.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/29075857.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/13477922.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/28035460.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/39413067.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/25990239.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/37764298.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/24889109.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/17688766.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/15297298.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/40018190.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/27536013.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/14789139.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/46260230.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/27485716.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/19796840.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/16533554.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/15118506.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/INFORMATION-TECHNOLOGY/32959732.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/28005884.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/25930778.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/36149549.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/28628090.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/36517781.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/64755882.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/24322804.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/13264796.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/44624796.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/55595908.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/20566550.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/55953734.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/19397727.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/47919212.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/96029688.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/32081266.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/21038022.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/64468610.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/27756469.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/31694970.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/82246962.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/10030015.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/60004873.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/10985403.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/54227873.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/13149176.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/17926546.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/77828437.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/38535335.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/19396040.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/26456899.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/23497307.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/11890896.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/12488356.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/19612167.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/38314236.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/17488801.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/27152464.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/81125166.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/31684925.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/86828820.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/22890839.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/33685075.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/28630325.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/28762662.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/28831378.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/56691064.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/31677347.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/61579998.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/14206561.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/23234047.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/14554542.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/16803215.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/30288581.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/17108676.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/22605864.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/21847415.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/16911115.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/28505854.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/86209934.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/35737840.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/14049846.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/26834746.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/28631840.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/12518008.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/10712803.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/39855211.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/20882041.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/49127329.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/38220146.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/20981299.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/21629057.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/28078163.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/82125182.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/11981094.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/74236636.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/19124258.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/35172961.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/32985311.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/51588273.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/25797445.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/25608963.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/12472574.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/50328713.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/27040860.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/24647794.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/39835894.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/90280583.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/62071407.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/35651876.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/17103000.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/47549345.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/28320387.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/35389360.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/19553067.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/23438227.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/47276718.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/25919149.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/30542184.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/12022566.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/25425322.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/30097175.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/10219099.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/10624813.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/15858254.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/15601399.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/15941675.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/37335325.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/21807224.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/17043822.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/43752620.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/12748557.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/12011623.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/21298336.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/15139979.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/32802563.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/28923650.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/ENGINEERING/18753367.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/CONSTRUCTION/25224998.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/CONSTRUCTION/29087505.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/CONSTRUCTION/31850269.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/CONSTRUCTION/27243670.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/CONSTRUCTION/22965804.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/CONSTRUCTION/12890045.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/CONSTRUCTION/10820510.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/CONSTRUCTION/32799518.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/CONSTRUCTION/34544955.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/CONSTRUCTION/10734870.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/CONSTRUCTION/88859947.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/CONSTRUCTION/39027764.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/CONSTRUCTION/61065616.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/CONSTRUCTION/25098739.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/CONSTRUCTION/29483501.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/CONSTRUCTION/10176013.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/CONSTRUCTION/26509539.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/CONSTRUCTION/29878348.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/CONSTRUCTION/29894080.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/CONSTRUCTION/18472240.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/CONSTRUCTION/20565849.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/CONSTRUCTION/14849103.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/CONSTRUCTION/28815362.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/CONSTRUCTION/78114950.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/CONSTRUCTION/36331163.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/CONSTRUCTION/17252448.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/CONSTRUCTION/35971546.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/CONSTRUCTION/26091595.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/CONSTRUCTION/14585273.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/CONSTRUCTION/39674782.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/CONSTRUCTION/19364677.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/CONSTRUCTION/30397268.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/CONSTRUCTION/28756444.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/CONSTRUCTION/32025286.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/CONSTRUCTION/17570634.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/CONSTRUCTION/19928941.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/CONSTRUCTION/25656981.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/CONSTRUCTION/29193505.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/CONSTRUCTION/13907230.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/CONSTRUCTION/24953126.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/CONSTRUCTION/16378091.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/CONSTRUCTION/16924279.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/CONSTRUCTION/22983516.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/CONSTRUCTION/27187994.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/CONSTRUCTION/12666174.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/CONSTRUCTION/12826414.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/CONSTRUCTION/12839152.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/CONSTRUCTION/29061628.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/CONSTRUCTION/28803888.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/CONSTRUCTION/24740005.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/CONSTRUCTION/27066370.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/CONSTRUCTION/10281555.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/CONSTRUCTION/12654876.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/CONSTRUCTION/32773331.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/CONSTRUCTION/56525735.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/CONSTRUCTION/71576860.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/CONSTRUCTION/44147689.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/CONSTRUCTION/14900898.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/CONSTRUCTION/51638201.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/CONSTRUCTION/63083944.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/CONSTRUCTION/29574501.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/CONSTRUCTION/11393213.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/CONSTRUCTION/22546476.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/CONSTRUCTION/15564893.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/CONSTRUCTION/24361598.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/CONSTRUCTION/10149490.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/CONSTRUCTION/16353584.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/CONSTRUCTION/33023370.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/CONSTRUCTION/33141415.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/CONSTRUCTION/10041713.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/CONSTRUCTION/93436805.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/CONSTRUCTION/22718826.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/CONSTRUCTION/11650031.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/CONSTRUCTION/32265203.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/CONSTRUCTION/15721849.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/CONSTRUCTION/12695537.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/CONSTRUCTION/25187733.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/CONSTRUCTION/22019500.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/CONSTRUCTION/18882984.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/CONSTRUCTION/63145386.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/CONSTRUCTION/21567392.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/CONSTRUCTION/24770846.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/CONSTRUCTION/28942221.pdf
# ...
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AUTOMOBILE/63989974.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AUTOMOBILE/11257723.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AUTOMOBILE/14455622.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AUTOMOBILE/47487091.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AUTOMOBILE/11152490.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AUTOMOBILE/32109048.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AUTOMOBILE/78357954.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AUTOMOBILE/97449528.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AUTOMOBILE/15210069.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AUTOMOBILE/16332293.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AUTOMOBILE/22732234.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AUTOMOBILE/84295343.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AUTOMOBILE/23009962.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AUTOMOBILE/99680385.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AUTOMOBILE/11887930.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AUTOMOBILE/11797122.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AUTOMOBILE/15484011.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AUTOMOBILE/82140102.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/AUTOMOBILE/26341645.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/14287992.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/22025574.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/27850777.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/14871762.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/16519708.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/11551946.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/65708020.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/31273310.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/20553895.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/23396633.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/24964303.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/12632728.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/27937592.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/39237915.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/12814706.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/25397102.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/91467795.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/15423153.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/32042584.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/13888506.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/22423839.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/79759716.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/28337049.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/34797369.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/27219200.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/30938994.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/19738730.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/14861855.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/14752209.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/18311419.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/17115815.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/18236085.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/17730889.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/29825044.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/27004930.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/24647386.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/15811992.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/36805025.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/27375577.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/27796199.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/14726000.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/32531824.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/18937778.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/38688388.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/67501448.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/12546838.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/26896699.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/18293620.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/61677751.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/26581830.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/31813535.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/37521676.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/27213082.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/77576845.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/89197180.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/20748929.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/32385553.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/82118447.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/12377803.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/38007664.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/10704573.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/16091352.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/12059198.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/95382114.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/14241621.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/25370801.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/98379112.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/19557384.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/20427934.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/14070138.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/18757174.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/37391947.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/29014805.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/47067533.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/14055971.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/27139412.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/14825300.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/20633855.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/13080868.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/81310245.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/12230301.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/36170003.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/17602815.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/40792022.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/25813953.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/24412546.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/22765255.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/26278597.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/10235211.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/17421910.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/16694152.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/33424600.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/31638814.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/36574147.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/10541358.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/15233524.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/14990354.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/29908929.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/39875803.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/76916835.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/34046031.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/59696315.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/13199813.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/28916894.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/13574264.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/29208172.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/17095812.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/10228751.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/10501991.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/17597372.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/16846478.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/90629382.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/11289482.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/20317319.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/11088337.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/20357858.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/10289113.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/35673335.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/80275976.pdf
# /root/.cache/kagglehub/datasets/snehaanbhawal/resume-dataset/versions/1/data/data/BUSINESS-DEVELOPMENT/23568641.pdf

# %%
from pdf2image import convert_from_path
import numpy as np

pdf_path = os.path.join(path_new, 'data' , 'data' , 'FITNESS' , '38650096.pdf')

pages = convert_from_path(pdf_path,dpi=300)

pdf_image = pages[0]

image = cv2.cvtColor(np.array(pdf_image) , cv2.COLOR_RGB2BGR)

display_image(image,"Sample Pdf Image")

# %% [markdown]
# # **PDF IMAGE PROCESSING**

# %%
##Using the Image Processing function defined earlier
import time

output_folder_path = '/content/sample_pdf_data'
start_time = time.time()

os.makedirs(output_folder_path,exist_ok=True)
print(f"Folder Created : {output_folder_path}")

for pdf_name in os.listdir(os.path.join(path_new,'data','data','FITNESS'))[:10]:
  print(f"Preprocessing Image : {pdf_name}")
  pdf_path = os.path.join(path_new , 'data' , 'data' , 'FITNESS' , pdf_name)

  pages = convert_from_path(pdf_path,dpi=300)
  pdf_image = pages[0]

  image = cv2.cvtColor(np.array(pdf_image) , cv2.COLOR_RGB2BGR)

  preprocessed_pdf_image = process_one_image(image)

  output_pdf_path = os.path.join(output_folder_path,pdf_name.replace('.pdf','.png'))
  cv2.imwrite(output_pdf_path , preprocessed_pdf_image)
  print(f"Saved processed pdf image to : {output_pdf_path}")
  print("-"*50)

  print(f"Processing Images is completed.")
  print(f"Total time taken : {time.time() - start_time} seconds")
# Out:
# Folder Created : /content/sample_pdf_data
# Preprocessing Image : 95769832.pdf
# Converted Image to Gray Scale
# Reduced Noise
# Binarized Image
# Detected Skew Angle : -0.29 degrees
# Deskewed Image
# Saved processed pdf image to : /content/sample_pdf_data/95769832.png
# --------------------------------------------------
# Processing Images is completed.
# Total time taken : 0.6217167377471924 seconds
# Preprocessing Image : 21122155.pdf
# Converted Image to Gray Scale
# Reduced Noise
# Binarized Image
# Detected Skew Angle : -0.00 degrees
# Deskewed Image
# Saved processed pdf image to : /content/sample_pdf_data/21122155.png
# --------------------------------------------------
# Processing Images is completed.
# Total time taken : 1.4609291553497314 seconds
# Preprocessing Image : 38650096.pdf
# Converted Image to Gray Scale
# Reduced Noise
# Binarized Image
# Detected Skew Angle : -0.00 degrees
# Deskewed Image
# Saved processed pdf image to : /content/sample_pdf_data/38650096.png
# --------------------------------------------------
# Processing Images is completed.
# Total time taken : 2.0327742099761963 seconds
# Preprocessing Image : 55746506.pdf
# Converted Image to Gray Scale
# Reduced Noise
# Binarized Image
# Detected Skew Angle : -0.00 degrees
# Deskewed Image
# Saved processed pdf image to : /content/sample_pdf_data/55746506.png
# --------------------------------------------------
# Processing Images is completed.
# Total time taken : 2.919311285018921 seconds
# Preprocessing Image : 35302620.pdf
# Converted Image to Gray Scale
# Reduced Noise
# Binarized Image
# Detected Skew Angle : -0.03 degrees
# Deskewed Image
# Saved processed pdf image to : /content/sample_pdf_data/35302620.png
# --------------------------------------------------
# Processing Images is completed.
# Total time taken : 4.0210254192352295 seconds
# Preprocessing Image : 32636041.pdf
# Converted Image to Gray Scale
# Reduced Noise
# Binarized Image
# Detected Skew Angle : -0.00 degrees
# Deskewed Image
# Saved processed pdf image to : /content/sample_pdf_data/32636041.png
# --------------------------------------------------
# Processing Images is completed.
# Total time taken : 5.138574600219727 seconds
# Preprocessing Image : 11332602.pdf
# Converted Image to Gray Scale
# Reduced Noise
# Binarized Image
# Detected Skew Angle : -0.00 degrees
# Deskewed Image
# Saved processed pdf image to : /content/sample_pdf_data/11332602.png
# --------------------------------------------------
# Processing Images is completed.
# Total time taken : 5.967918395996094 seconds
# Preprocessing Image : 34792238.pdf
# Converted Image to Gray Scale
# Reduced Noise
# Binarized Image
# Detected Skew Angle : 0.83 degrees
# Deskewed Image
# Saved processed pdf image to : /content/sample_pdf_data/34792238.png
# --------------------------------------------------
# Processing Images is completed.
# Total time taken : 6.929880619049072 seconds
# Preprocessing Image : 19938081.pdf
# Converted Image to Gray Scale
# Reduced Noise
# Binarized Image
# Detected Skew Angle : 0.03 degrees
# Deskewed Image
# Saved processed pdf image to : /content/sample_pdf_data/19938081.png
# --------------------------------------------------
# Processing Images is completed.
# Total time taken : 7.829139232635498 seconds
# Preprocessing Image : 30757456.pdf
# Converted Image to Gray Scale
# Reduced Noise
# Binarized Image
# Detected Skew Angle : 0.04 degrees
# Deskewed Image
# Saved processed pdf image to : /content/sample_pdf_data/30757456.png
# --------------------------------------------------
# Processing Images is completed.
# Total time taken : 8.957292079925537 seconds

# %% [markdown]
# # **TEXT EXTRACTION**

# %%
from PIL import Image
import pytesseract
import os
import time

output_text_path = '/content/extracted_output'
input_folder_path = '/content/sample_pdf_data'
start_time = time.time()

os.makedirs(output_text_path,exist_ok=True)
print(f"Created Folder : {output_text_path}")

total_images = sum(1 for entry in os.scandir(input_folder_path))
print(f"Total images in folder : {total_images}")

for i , pdf_name in enumerate(os.listdir(input_folder_path)[:10],1):
  print(f"Processing Image : {i}/{total_images} // {pdf_name}")

  image_path = os.path.join(input_folder_path,pdf_name)
  print(f'Extracting Text...')
  text = pytesseract.image_to_string(Image.open(image_path))
  with open(output_path ,'w') as f:
    f.write(text)
  output_path = os.path.join(output_text_path,pdf_name.replace('.png','.txt'))

  print(f"Saved extracted text to {output_path}")
  print("-"*50)

print("Text Extraction Completed.")
print(f"Total time taken: {time.time() - start_time} seconds")
print(f"--------------------------------------------------------------")
# Out:
# Created Folder : /content/extracted_output
# Total images in folder : 10
# Processing Image : 1/10 // 95769832.png
# Extracting Text...
# Saved extracted text to /content/extracted_output/95769832.txt
# --------------------------------------------------
# Processing Image : 2/10 // 21122155.png
# Extracting Text...
# Saved extracted text to /content/extracted_output/21122155.txt
# --------------------------------------------------
# Processing Image : 3/10 // 32636041.png
# Extracting Text...
# Saved extracted text to /content/extracted_output/32636041.txt
# --------------------------------------------------
# Processing Image : 4/10 // 35302620.png
# Extracting Text...
# Saved extracted text to /content/extracted_output/35302620.txt
# --------------------------------------------------
# Processing Image : 5/10 // 55746506.png
# Extracting Text...
# Saved extracted text to /content/extracted_output/55746506.txt
# --------------------------------------------------
# Processing Image : 6/10 // 34792238.png
# Extracting Text...
# Saved extracted text to /content/extracted_output/34792238.txt
# --------------------------------------------------
# Processing Image : 7/10 // 30757456.png
# Extracting Text...
# Saved extracted text to /content/extracted_output/30757456.txt
# --------------------------------------------------
# Processing Image : 8/10 // 19938081.png
# Extracting Text...
# Saved extracted text to /content/extracted_output/19938081.txt
# --------------------------------------------------
# Processing Image : 9/10 // 11332602.png
# Extracting Text...
# Saved extracted text to /content/extracted_output/11332602.txt
# --------------------------------------------------
# Processing Image : 10/10 // 38650096.png
# Extracting Text...
# Saved extracted text to /content/extracted_output/38650096.txt
# --------------------------------------------------
# Text Extraction Completed.
# Total time taken: 190.87722086906433 seconds
# --------------------------------------------------------------

# %% [markdown]
# # **INFORMATION EXTRACTION**

# %%
prompt_pdf = """
# Resume Information Extraction Prompt

Extract the relevant information from the given resume image.

**Information to be extracted:**
- Name
- Email
- Phone
- Address
- Education (degree, university, year)
- Skills
- Work Experience (company, role, duration)
- Projects (name, description, duration)

The resume image has been:
- Converted to grayscale
- Noise reduced
- Binarized
- Deskewed using OpenCV

Always give your response in the following JSON format:

```json
{
    "name": "NAME",
    "email": "EMAIL",
    "phone": "PHONE_NUMBER",
    "address": "ADDRESS",
    "education": [
        {
            "degree": "DEGREE",
            "university": "UNIVERSITY",
            "year": "YEAR"
        }
    ],
    "skills": ["SKILL_1", "SKILL_2", "..."],
    "work_experience": [
        {
            "company": "COMPANY_NAME",
            "role": "ROLE",
            "duration": "DURATION"
        }
    ],
    "projects": [
        {
            "name": "PROJECT_NAME",
            "description": "DESCRIPTION",
            "duration": "DURATION"
        }
    ]
}

## Additional Instructions

- The text has been extracted from the resume image using **Tesseract OCR**.
- Use the extracted text as support for extracting information.
- If you find any information incorrectly extracted, correct it yourself.
- Respond **only** in the specified JSON format.


### Extracted Text from Resume
Here is the text extracted from the resume:

"""

# %%
image_folder_path = '/content/sample_pdf_data'
text_folder_path = '/content/extracted_output'
output_folder_path = '/content/pdf_json_output'

start_time = time.time()

os.makedirs(output_folder_path,exist_ok=True)
print(f"Created Folder : {output_folder_path}")

total_images = sum(1 for entry in os.scandir(image_folder_path))
print(f"Total images in folder : {total_images}")

for i , pdf_name in enumerate(os.listdir(image_folder_path)[:5],1):
  print(f"Processing Image : {i}/{total_images} // {pdf_name}")

  image_path = os.path.join(image_folder_path , pdf_name)
  with open(image_path,"rb") as f:
    image = Image.open(image_path)

  text_path = os.path.join(text_folder_path , pdf_name.replace(".png",".txt"))
  with open(text_path , "r") as f:
    text = f.read()

  prompt = prompt_pdf + text

  contents = [ image , {"text" : prompt} ]

  response = genai_client.models.generate_content(model='gemini-2.5-flash',contents=contents)

  usage_metadata = response.usage_metadata
  print(f"Input Token Count: {usage_metadata.prompt_token_count}")
  print(f"Thoughts Token Count: {response.usage_metadata.thoughts_token_count}")
  print(f"Output Token Count: {usage_metadata.candidates_token_count}")
  print(f"Total Token Count: {usage_metadata.total_token_count}")

  output_text = response.text
  clean_text = output_text.replace('```json', '').replace('```', '').strip()
  extracted_information = json.loads(clean_text)

  # output_path = os.path.join(output_folder_path , pdf_name.replace(".png",".json"))
  with open(output_path,"w") as f:
    json.dump(extracted_information, f, indent=4)

  print(f"Saved extracted text to {output_path}")
  time.sleep(10)

  print("Information Extraction Completed")
  print(f"Time Taken : {time.time() - start_time} seconds")
  print(f"-------------------------------------------------------------------------")
# Out:
# Created Folder : /content/pdf_json_output
# Total images in folder : 10
# Processing Image : 1/10 // 95769832.png
# Input Token Count: 1613
# Thoughts Token Count: 2678
# Output Token Count: 393
# Total Token Count: 4684
# Saved extracted text to /content/pdf_json_output/55746506.json
# Information Extraction Completed
# Time Taken : 28.242072105407715 seconds
# -------------------------------------------------------------------------
# Processing Image : 2/10 // 21122155.png
# Input Token Count: 1492
# Thoughts Token Count: 2513
# Output Token Count: 408
# Total Token Count: 4413
# Saved extracted text to /content/pdf_json_output/55746506.json
# Information Extraction Completed
# Time Taken : 56.27708601951599 seconds
# -------------------------------------------------------------------------
# Processing Image : 3/10 // 32636041.png
# Input Token Count: 1367
# Thoughts Token Count: 2361
# Output Token Count: 436
# Total Token Count: 4164
# Saved extracted text to /content/pdf_json_output/55746506.json
# Information Extraction Completed
# Time Taken : 82.28979706764221 seconds
# -------------------------------------------------------------------------
# Processing Image : 4/10 // 35302620.png
# Input Token Count: 1511
# Thoughts Token Count: 6649
# Output Token Count: 428
# Total Token Count: 8588
# Saved extracted text to /content/pdf_json_output/55746506.json
# Information Extraction Completed
# Time Taken : 127.70229291915894 seconds
# -------------------------------------------------------------------------
# Processing Image : 5/10 // 55746506.png
# Input Token Count: 1677
# Thoughts Token Count: 4451
# Output Token Count: 435
# Total Token Count: 6563
# Saved extracted text to /content/pdf_json_output/55746506.json
# Information Extraction Completed
# Time Taken : 169.86953234672546 seconds
# -------------------------------------------------------------------------
