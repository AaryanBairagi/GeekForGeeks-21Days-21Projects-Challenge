# %%
# !pip install crawl4ai
# Out:
# Collecting crawl4ai
#   Downloading crawl4ai-0.7.4-py3-none-any.whl.metadata (39 kB)
# Collecting aiofiles>=24.1.0 (from crawl4ai)
#   Downloading aiofiles-24.1.0-py3-none-any.whl.metadata (10 kB)
# Collecting aiohttp>=3.11.11 (from crawl4ai)
#   Using cached aiohttp-3.12.15-cp313-cp313-win_amd64.whl.metadata (7.9 kB)
# Collecting aiosqlite~=0.20 (from crawl4ai)
#   Downloading aiosqlite-0.21.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: anyio>=4.0.0 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from crawl4ai) (4.9.0)
# Collecting lxml~=5.3 (from crawl4ai)
#   Downloading lxml-5.4.0-cp313-cp313-win_amd64.whl.metadata (3.6 kB)
# Collecting litellm>=1.53.1 (from crawl4ai)
#   Downloading litellm-1.77.5-py3-none-any.whl.metadata (42 kB)
# Requirement already satisfied: numpy<3,>=1.26.0 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from crawl4ai) (2.2.5)
# Requirement already satisfied: pillow>=10.4 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from crawl4ai) (11.2.1)
# Collecting playwright>=1.49.0 (from crawl4ai)
#   Downloading playwright-1.55.0-py3-none-win_amd64.whl.metadata (3.5 kB)
# Collecting patchright>=1.49.0 (from crawl4ai)
#   Downloading patchright-1.55.2-py3-none-win_amd64.whl.metadata (12 kB)
# Collecting python-dotenv~=1.0 (from crawl4ai)
#   Downloading python_dotenv-1.1.1-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: requests~=2.26 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from crawl4ai) (2.32.3)
# Requirement already satisfied: beautifulsoup4~=4.12 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from crawl4ai) (4.13.4)
# Collecting tf-playwright-stealth>=1.1.0 (from crawl4ai)
#   Downloading tf_playwright_stealth-1.2.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting xxhash~=3.4 (from crawl4ai)
#   Downloading xxhash-3.5.0-cp313-cp313-win_amd64.whl.metadata (13 kB)
# Collecting rank-bm25~=0.2 (from crawl4ai)
#   Downloading rank_bm25-0.2.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting snowballstemmer~=2.2 (from crawl4ai)
#   Downloading snowballstemmer-2.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting pydantic>=2.10 (from crawl4ai)
#   Downloading pydantic-2.11.9-py3-none-any.whl.metadata (68 kB)
# Collecting pyOpenSSL>=24.3.0 (from crawl4ai)
#   Downloading pyopenssl-25.3.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: psutil>=6.1.1 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from crawl4ai) (7.0.0)
# Requirement already satisfied: PyYAML>=6.0 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from crawl4ai) (6.0.2)
# Collecting nltk>=3.9.1 (from crawl4ai)
#   Using cached nltk-3.9.1-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: rich>=13.9.4 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from crawl4ai) (14.1.0)
# Requirement already satisfied: httpx>=0.27.2 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from crawl4ai) (0.28.1)
# Collecting fake-useragent>=2.0.3 (from crawl4ai)
#   Downloading fake_useragent-2.2.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: click>=8.1.7 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from crawl4ai) (8.1.8)
# Collecting chardet>=5.2.0 (from crawl4ai)
#   Downloading chardet-5.2.0-py3-none-any.whl.metadata (3.4 kB)
# Collecting brotli>=1.1.0 (from crawl4ai)
#   Downloading Brotli-1.1.0-cp313-cp313-win_amd64.whl.metadata (5.6 kB)
# Collecting humanize>=4.10.0 (from crawl4ai)
#   Downloading humanize-4.13.0-py3-none-any.whl.metadata (7.8 kB)
# Collecting lark>=1.2.2 (from crawl4ai)
#   Downloading lark-1.3.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting alphashape>=1.3.1 (from crawl4ai)
#   Downloading alphashape-1.3.1-py2.py3-none-any.whl.metadata (18 kB)
# Collecting shapely>=2.0.0 (from crawl4ai)
#   Downloading shapely-2.1.2-cp313-cp313-win_amd64.whl.metadata (7.1 kB)
# Requirement already satisfied: typing_extensions>=4.0 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from aiosqlite~=0.20->crawl4ai) (4.13.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from beautifulsoup4~=4.12->crawl4ai) (2.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from requests~=2.26->crawl4ai) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from requests~=2.26->crawl4ai) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from requests~=2.26->crawl4ai) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from requests~=2.26->crawl4ai) (2025.1.31)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp>=3.11.11->crawl4ai)
#   Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp>=3.11.11->crawl4ai)
#   Downloading aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from aiohttp>=3.11.11->crawl4ai) (25.3.0)
# Collecting frozenlist>=1.1.1 (from aiohttp>=3.11.11->crawl4ai)
#   Downloading frozenlist-1.7.0-cp313-cp313-win_amd64.whl.metadata (19 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp>=3.11.11->crawl4ai)
#   Downloading multidict-6.6.4-cp313-cp313-win_amd64.whl.metadata (5.4 kB)
# Collecting propcache>=0.2.0 (from aiohttp>=3.11.11->crawl4ai)
#   Downloading propcache-0.3.2-cp313-cp313-win_amd64.whl.metadata (12 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp>=3.11.11->crawl4ai)
#   Downloading yarl-1.20.1-cp313-cp313-win_amd64.whl.metadata (76 kB)
# Collecting click-log>=0.3.2 (from alphashape>=1.3.1->crawl4ai)
#   Downloading click_log-0.4.0-py2.py3-none-any.whl.metadata (1.2 kB)
# Collecting trimesh>=3.9.8 (from alphashape>=1.3.1->crawl4ai)
#   Downloading trimesh-4.8.3-py3-none-any.whl.metadata (18 kB)
# Collecting networkx>=2.5 (from alphashape>=1.3.1->crawl4ai)
#   Downloading networkx-3.5-py3-none-any.whl.metadata (6.3 kB)
# Collecting rtree>=0.9.7 (from alphashape>=1.3.1->crawl4ai)
#   Downloading rtree-1.4.1-py3-none-win_amd64.whl.metadata (2.2 kB)
# Requirement already satisfied: scipy>=1.0.0 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from alphashape>=1.3.1->crawl4ai) (1.15.2)
# Requirement already satisfied: sniffio>=1.1 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from anyio>=4.0.0->crawl4ai) (1.3.1)
# Requirement already satisfied: colorama in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from click>=8.1.7->crawl4ai) (0.4.6)
# Requirement already satisfied: httpcore==1.* in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from httpx>=0.27.2->crawl4ai) (1.0.8)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from httpcore==1.*->httpx>=0.27.2->crawl4ai) (0.14.0)
# Collecting h2<5,>=3 (from httpx[http2]>=0.27.2->crawl4ai)
#   Downloading h2-4.3.0-py3-none-any.whl.metadata (5.1 kB)
# Collecting hyperframe<7,>=6.1 (from h2<5,>=3->httpx[http2]>=0.27.2->crawl4ai)
#   Downloading hyperframe-6.1.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting hpack<5,>=4.1 (from h2<5,>=3->httpx[http2]>=0.27.2->crawl4ai)
#   Downloading hpack-4.1.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting fastuuid>=0.13.0 (from litellm>=1.53.1->crawl4ai)
#   Downloading fastuuid-0.13.5-cp313-cp313-win_amd64.whl.metadata (1.0 kB)
# Collecting importlib-metadata>=6.8.0 (from litellm>=1.53.1->crawl4ai)
#   Downloading importlib_metadata-8.7.0-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.2 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from litellm>=1.53.1->crawl4ai) (3.1.6)
# Requirement already satisfied: jsonschema<5.0.0,>=4.22.0 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from litellm>=1.53.1->crawl4ai) (4.23.0)
# Collecting openai>=1.99.5 (from litellm>=1.53.1->crawl4ai)
#   Downloading openai-2.0.0-py3-none-any.whl.metadata (29 kB)
# Collecting tiktoken>=0.7.0 (from litellm>=1.53.1->crawl4ai)
#   Downloading tiktoken-0.11.0-cp313-cp313-win_amd64.whl.metadata (6.9 kB)
# Collecting tokenizers (from litellm>=1.53.1->crawl4ai)
#   Downloading tokenizers-0.22.1-cp39-abi3-win_amd64.whl.metadata (6.9 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from jinja2<4.0.0,>=3.1.2->litellm>=1.53.1->crawl4ai) (3.0.2)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from jsonschema<5.0.0,>=4.22.0->litellm>=1.53.1->crawl4ai) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from jsonschema<5.0.0,>=4.22.0->litellm>=1.53.1->crawl4ai) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from jsonschema<5.0.0,>=4.22.0->litellm>=1.53.1->crawl4ai) (0.24.0)
# Collecting annotated-types>=0.6.0 (from pydantic>=2.10->crawl4ai)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.33.2 (from pydantic>=2.10->crawl4ai)
#   Downloading pydantic_core-2.33.2-cp313-cp313-win_amd64.whl.metadata (6.9 kB)
# Collecting typing-inspection>=0.4.0 (from pydantic>=2.10->crawl4ai)
#   Downloading typing_inspection-0.4.1-py3-none-any.whl.metadata (2.6 kB)
# Collecting zipp>=3.20 (from importlib-metadata>=6.8.0->litellm>=1.53.1->crawl4ai)
#   Downloading zipp-3.23.0-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: joblib in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from nltk>=3.9.1->crawl4ai) (1.4.2)
# Collecting regex>=2021.8.3 (from nltk>=3.9.1->crawl4ai)
#   Downloading regex-2025.9.18-cp313-cp313-win_amd64.whl.metadata (41 kB)
# Requirement already satisfied: tqdm in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from nltk>=3.9.1->crawl4ai) (4.67.1)
# Collecting distro<2,>=1.7.0 (from openai>=1.99.5->litellm>=1.53.1->crawl4ai)
#   Downloading distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting jiter<1,>=0.4.0 (from openai>=1.99.5->litellm>=1.53.1->crawl4ai)
#   Downloading jiter-0.11.0-cp313-cp313-win_amd64.whl.metadata (5.3 kB)
# Collecting pyee<14,>=13 (from patchright>=1.49.0->crawl4ai)
#   Downloading pyee-13.0.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting greenlet<4.0.0,>=3.1.1 (from patchright>=1.49.0->crawl4ai)
#   Downloading greenlet-3.2.4-cp313-cp313-win_amd64.whl.metadata (4.2 kB)
# Collecting cryptography<47,>=45.0.7 (from pyOpenSSL>=24.3.0->crawl4ai)
#   Downloading cryptography-46.0.1-cp311-abi3-win_amd64.whl.metadata (5.7 kB)
# Collecting cffi>=2.0.0 (from cryptography<47,>=45.0.7->pyOpenSSL>=24.3.0->crawl4ai)
#   Downloading cffi-2.0.0-cp313-cp313-win_amd64.whl.metadata (2.6 kB)
# Requirement already satisfied: pycparser in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from cffi>=2.0.0->cryptography<47,>=45.0.7->pyOpenSSL>=24.3.0->crawl4ai) (2.22)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from rich>=13.9.4->crawl4ai) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from rich>=13.9.4->crawl4ai) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.9.4->crawl4ai) (0.1.2)
# Collecting fake-http-header<0.4.0,>=0.3.5 (from tf-playwright-stealth>=1.1.0->crawl4ai)
#   Downloading fake_http_header-0.3.5-py3-none-any.whl.metadata (3.5 kB)
# Collecting huggingface-hub<2.0,>=0.16.4 (from tokenizers->litellm>=1.53.1->crawl4ai)
#   Downloading huggingface_hub-0.35.3-py3-none-any.whl.metadata (14 kB)
# Collecting filelock (from huggingface-hub<2.0,>=0.16.4->tokenizers->litellm>=1.53.1->crawl4ai)
#   Downloading filelock-3.19.1-py3-none-any.whl.metadata (2.1 kB)
# Collecting fsspec>=2023.5.0 (from huggingface-hub<2.0,>=0.16.4->tokenizers->litellm>=1.53.1->crawl4ai)
#   Downloading fsspec-2025.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: packaging>=20.9 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->litellm>=1.53.1->crawl4ai) (25.0)
# Downloading crawl4ai-0.7.4-py3-none-any.whl (426 kB)
# Downloading aiosqlite-0.21.0-py3-none-any.whl (15 kB)
# Downloading lxml-5.4.0-cp313-cp313-win_amd64.whl (3.8 MB)
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------- ----------------------------- 1.0/3.8 MB 5.4 MB/s eta 0:00:01
#    ------------------- -------------------- 1.8/3.8 MB 4.3 MB/s eta 0:00:01
#    ------------------------------ --------- 2.9/3.8 MB 4.1 MB/s eta 0:00:01
#    -------------------------------------- - 3.7/3.8 MB 4.0 MB/s eta 0:00:01
#    ---------------------------------------- 3.8/3.8 MB 3.8 MB/s  0:00:00
# Downloading python_dotenv-1.1.1-py3-none-any.whl (20 kB)
# Downloading rank_bm25-0.2.2-py3-none-any.whl (8.6 kB)
# Downloading snowballstemmer-2.2.0-py2.py3-none-any.whl (93 kB)
# Downloading xxhash-3.5.0-cp313-cp313-win_amd64.whl (30 kB)
# Downloading aiofiles-24.1.0-py3-none-any.whl (15 kB)
# Downloading aiohttp-3.12.15-cp313-cp313-win_amd64.whl (449 kB)
# Downloading multidict-6.6.4-cp313-cp313-win_amd64.whl (45 kB)
# Downloading yarl-1.20.1-cp313-cp313-win_amd64.whl (86 kB)
# Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Downloading aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Downloading alphashape-1.3.1-py2.py3-none-any.whl (13 kB)
# Downloading Brotli-1.1.0-cp313-cp313-win_amd64.whl (358 kB)
# Downloading chardet-5.2.0-py3-none-any.whl (199 kB)
# Downloading click_log-0.4.0-py2.py3-none-any.whl (4.3 kB)
# Downloading fake_useragent-2.2.0-py3-none-any.whl (161 kB)
# Downloading frozenlist-1.7.0-cp313-cp313-win_amd64.whl (43 kB)
# Downloading h2-4.3.0-py3-none-any.whl (61 kB)
# Downloading hpack-4.1.0-py3-none-any.whl (34 kB)
# Downloading hyperframe-6.1.0-py3-none-any.whl (13 kB)
# Downloading humanize-4.13.0-py3-none-any.whl (128 kB)
# Downloading lark-1.3.0-py3-none-any.whl (113 kB)
# Downloading litellm-1.77.5-py3-none-any.whl (9.2 MB)
#    ---------------------------------------- 0.0/9.2 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/9.2 MB 5.0 MB/s eta 0:00:02
#    -------- ------------------------------- 1.8/9.2 MB 4.7 MB/s eta 0:00:02
#    ----------- ---------------------------- 2.6/9.2 MB 4.2 MB/s eta 0:00:02
#    -------------- ------------------------- 3.4/9.2 MB 4.2 MB/s eta 0:00:02
#    ------------------ --------------------- 4.2/9.2 MB 4.0 MB/s eta 0:00:02
#    --------------------- ------------------ 5.0/9.2 MB 4.0 MB/s eta 0:00:02
#    ------------------------- -------------- 5.8/9.2 MB 3.9 MB/s eta 0:00:01
#    ---------------------------- ----------- 6.6/9.2 MB 3.9 MB/s eta 0:00:01
#    -------------------------------- ------- 7.3/9.2 MB 3.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 8.1/9.2 MB 3.8 MB/s eta 0:00:01
#    -------------------------------------- - 8.9/9.2 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------- 9.2/9.2 MB 3.8 MB/s  0:00:02
# Downloading pydantic-2.11.9-py3-none-any.whl (444 kB)
# Downloading pydantic_core-2.33.2-cp313-cp313-win_amd64.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------- ----------------------- 0.8/2.0 MB 3.8 MB/s eta 0:00:01
#    -------------------------------- ------- 1.6/2.0 MB 4.2 MB/s eta 0:00:01
#    ---------------------------------------- 2.0/2.0 MB 3.9 MB/s  0:00:00
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading fastuuid-0.13.5-cp313-cp313-win_amd64.whl (150 kB)
# Downloading importlib_metadata-8.7.0-py3-none-any.whl (27 kB)
# Downloading networkx-3.5-py3-none-any.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    --------------- ------------------------ 0.8/2.0 MB 4.3 MB/s eta 0:00:01
#    ------------------------------ --------- 1.6/2.0 MB 4.4 MB/s eta 0:00:01
#    ---------------------------------------- 2.0/2.0 MB 4.1 MB/s  0:00:00
# Downloading nltk-3.9.1-py3-none-any.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ------------- -------------------------- 0.5/1.5 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 1.3/1.5 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------- 1.5/1.5 MB 3.4 MB/s  0:00:00
# Downloading openai-2.0.0-py3-none-any.whl (955 kB)
#    ---------------------------------------- 0.0/955.5 kB ? eta -:--:--
#    --------------------- ------------------ 524.3/955.5 kB 3.7 MB/s eta 0:00:01
#    ---------------------------------------- 955.5/955.5 kB 3.4 MB/s  0:00:00
# Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading jiter-0.11.0-cp313-cp313-win_amd64.whl (202 kB)
# Downloading patchright-1.55.2-py3-none-win_amd64.whl (35.5 MB)
#    ---------------------------------------- 0.0/35.5 MB ? eta -:--:--
#     --------------------------------------- 0.8/35.5 MB 4.0 MB/s eta 0:00:09
#    - -------------------------------------- 1.6/35.5 MB 4.0 MB/s eta 0:00:09
#    -- ------------------------------------- 2.4/35.5 MB 4.1 MB/s eta 0:00:09
#    --- ------------------------------------ 3.4/35.5 MB 4.1 MB/s eta 0:00:08
#    ---- ----------------------------------- 4.2/35.5 MB 4.0 MB/s eta 0:00:08
#    ----- ---------------------------------- 5.0/35.5 MB 4.0 MB/s eta 0:00:08
#    ------ --------------------------------- 5.8/35.5 MB 3.9 MB/s eta 0:00:08
#    ------- -------------------------------- 6.6/35.5 MB 3.8 MB/s eta 0:00:08
#    -------- ------------------------------- 7.3/35.5 MB 3.8 MB/s eta 0:00:08
#    --------- ------------------------------ 8.1/35.5 MB 3.8 MB/s eta 0:00:08
#    ---------- ----------------------------- 9.2/35.5 MB 3.9 MB/s eta 0:00:07
#    ----------- ---------------------------- 10.0/35.5 MB 3.9 MB/s eta 0:00:07
#    ------------ --------------------------- 10.7/35.5 MB 3.8 MB/s eta 0:00:07
#    ------------- -------------------------- 11.5/35.5 MB 3.8 MB/s eta 0:00:07
#    ------------- -------------------------- 12.3/35.5 MB 3.8 MB/s eta 0:00:07
#    -------------- ------------------------- 13.1/35.5 MB 3.8 MB/s eta 0:00:06
#    --------------- ------------------------ 13.9/35.5 MB 3.8 MB/s eta 0:00:06
#    ---------------- ----------------------- 14.7/35.5 MB 3.8 MB/s eta 0:00:06
#    ----------------- ---------------------- 15.5/35.5 MB 3.8 MB/s eta 0:00:06
#    ------------------ --------------------- 16.5/35.5 MB 3.8 MB/s eta 0:00:05
#    ------------------- -------------------- 17.3/35.5 MB 3.8 MB/s eta 0:00:05
#    -------------------- ------------------- 18.1/35.5 MB 3.8 MB/s eta 0:00:05
#    --------------------- ------------------ 18.9/35.5 MB 3.8 MB/s eta 0:00:05
#    ---------------------- ----------------- 19.7/35.5 MB 3.8 MB/s eta 0:00:05
#    ----------------------- ---------------- 20.4/35.5 MB 3.8 MB/s eta 0:00:04
#    ----------------------- ---------------- 21.2/35.5 MB 3.8 MB/s eta 0:00:04
#    ------------------------ --------------- 22.0/35.5 MB 3.8 MB/s eta 0:00:04
#    ------------------------- -------------- 22.8/35.5 MB 3.8 MB/s eta 0:00:04
#    -------------------------- ------------- 23.6/35.5 MB 3.8 MB/s eta 0:00:04
#    --------------------------- ------------ 24.4/35.5 MB 3.8 MB/s eta 0:00:03
#    ---------------------------- ----------- 25.2/35.5 MB 3.8 MB/s eta 0:00:03
#    ----------------------------- ---------- 26.2/35.5 MB 3.8 MB/s eta 0:00:03
#    ------------------------------ --------- 27.0/35.5 MB 3.8 MB/s eta 0:00:03
#    ------------------------------- -------- 27.8/35.5 MB 3.8 MB/s eta 0:00:03
#    -------------------------------- ------- 28.6/35.5 MB 3.8 MB/s eta 0:00:02
#    --------------------------------- ------ 29.4/35.5 MB 3.8 MB/s eta 0:00:02
#    ---------------------------------- ----- 30.1/35.5 MB 3.8 MB/s eta 0:00:02
#    ----------------------------------- ---- 31.2/35.5 MB 3.8 MB/s eta 0:00:02
#    ----------------------------------- ---- 31.7/35.5 MB 3.8 MB/s eta 0:00:01
#    ------------------------------------ --- 32.8/35.5 MB 3.8 MB/s eta 0:00:01
#    ------------------------------------- -- 33.6/35.5 MB 3.8 MB/s eta 0:00:01
#    -------------------------------------- - 34.3/35.5 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------  35.1/35.5 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------- 35.5/35.5 MB 3.7 MB/s  0:00:09
# Downloading greenlet-3.2.4-cp313-cp313-win_amd64.whl (299 kB)
# Downloading pyee-13.0.0-py3-none-any.whl (15 kB)
# Downloading playwright-1.55.0-py3-none-win_amd64.whl (35.5 MB)
#    ---------------------------------------- 0.0/35.5 MB ? eta -:--:--
#     --------------------------------------- 0.8/35.5 MB 4.2 MB/s eta 0:00:09
#    -- ------------------------------------- 1.8/35.5 MB 4.4 MB/s eta 0:00:08
#    -- ------------------------------------- 2.6/35.5 MB 4.4 MB/s eta 0:00:08
#    --- ------------------------------------ 3.4/35.5 MB 4.2 MB/s eta 0:00:08
#    ---- ----------------------------------- 4.2/35.5 MB 4.1 MB/s eta 0:00:08
#    ----- ---------------------------------- 5.0/35.5 MB 4.0 MB/s eta 0:00:08
#    ------ --------------------------------- 5.5/35.5 MB 3.8 MB/s eta 0:00:08
#    ------- -------------------------------- 6.3/35.5 MB 3.7 MB/s eta 0:00:08
#    -------- ------------------------------- 7.3/35.5 MB 3.7 MB/s eta 0:00:08
#    --------- ------------------------------ 8.1/35.5 MB 3.8 MB/s eta 0:00:08
#    ---------- ----------------------------- 9.2/35.5 MB 3.8 MB/s eta 0:00:07
#    ----------- ---------------------------- 10.0/35.5 MB 3.8 MB/s eta 0:00:07
#    ------------ --------------------------- 10.7/35.5 MB 3.8 MB/s eta 0:00:07
#    ------------- -------------------------- 11.5/35.5 MB 3.8 MB/s eta 0:00:07
#    ------------- -------------------------- 12.3/35.5 MB 3.8 MB/s eta 0:00:07
#    -------------- ------------------------- 13.1/35.5 MB 3.8 MB/s eta 0:00:06
#    --------------- ------------------------ 14.2/35.5 MB 3.8 MB/s eta 0:00:06
#    ---------------- ----------------------- 14.9/35.5 MB 3.8 MB/s eta 0:00:06
#    ----------------- ---------------------- 15.7/35.5 MB 3.8 MB/s eta 0:00:06
#    ------------------ --------------------- 16.5/35.5 MB 3.8 MB/s eta 0:00:05
#    ------------------- -------------------- 17.3/35.5 MB 3.8 MB/s eta 0:00:05
#    -------------------- ------------------- 18.1/35.5 MB 3.8 MB/s eta 0:00:05
#    --------------------- ------------------ 18.9/35.5 MB 3.8 MB/s eta 0:00:05
#    ---------------------- ----------------- 19.7/35.5 MB 3.8 MB/s eta 0:00:05
#    ----------------------- ---------------- 20.7/35.5 MB 3.8 MB/s eta 0:00:04
#    ------------------------ --------------- 21.5/35.5 MB 3.8 MB/s eta 0:00:04
#    ------------------------- -------------- 22.3/35.5 MB 3.8 MB/s eta 0:00:04
#    -------------------------- ------------- 23.1/35.5 MB 3.8 MB/s eta 0:00:04
#    -------------------------- ------------- 23.9/35.5 MB 3.8 MB/s eta 0:00:04
#    --------------------------- ------------ 24.6/35.5 MB 3.8 MB/s eta 0:00:03
#    ---------------------------- ----------- 25.4/35.5 MB 3.8 MB/s eta 0:00:03
#    ----------------------------- ---------- 26.2/35.5 MB 3.8 MB/s eta 0:00:03
#    ------------------------------ --------- 27.0/35.5 MB 3.8 MB/s eta 0:00:03
#    ------------------------------- -------- 28.0/35.5 MB 3.8 MB/s eta 0:00:02
#    -------------------------------- ------- 28.8/35.5 MB 3.8 MB/s eta 0:00:02
#    --------------------------------- ------ 29.6/35.5 MB 3.8 MB/s eta 0:00:02
#    ---------------------------------- ----- 30.4/35.5 MB 3.8 MB/s eta 0:00:02
#    ----------------------------------- ---- 31.2/35.5 MB 3.8 MB/s eta 0:00:02
#    ------------------------------------ --- 32.0/35.5 MB 3.8 MB/s eta 0:00:01
#    ------------------------------------ --- 32.8/35.5 MB 3.8 MB/s eta 0:00:01
#    -------------------------------------- - 33.8/35.5 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------  34.6/35.5 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------  35.4/35.5 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------  35.4/35.5 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------- 35.5/35.5 MB 3.7 MB/s  0:00:09
# Downloading propcache-0.3.2-cp313-cp313-win_amd64.whl (40 kB)
# Downloading pyopenssl-25.3.0-py3-none-any.whl (57 kB)
# Downloading cryptography-46.0.1-cp311-abi3-win_amd64.whl (3.5 MB)
#    ---------------------------------------- 0.0/3.5 MB ? eta -:--:--
#    -------- ------------------------------- 0.8/3.5 MB 3.9 MB/s eta 0:00:01
#    ----------------- ---------------------- 1.6/3.5 MB 4.3 MB/s eta 0:00:01
#    ----------------------------- ---------- 2.6/3.5 MB 4.3 MB/s eta 0:00:01
#    -------------------------------------- - 3.4/3.5 MB 4.2 MB/s eta 0:00:01
#    ---------------------------------------- 3.5/3.5 MB 4.0 MB/s  0:00:00
# Downloading cffi-2.0.0-cp313-cp313-win_amd64.whl (183 kB)
# Downloading regex-2025.9.18-cp313-cp313-win_amd64.whl (275 kB)
# Downloading rtree-1.4.1-py3-none-win_amd64.whl (389 kB)
# Downloading shapely-2.1.2-cp313-cp313-win_amd64.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ------------------ --------------------- 0.8/1.7 MB 4.2 MB/s eta 0:00:01
#    ---------------------------------------- 1.7/1.7 MB 4.0 MB/s  0:00:00
# Downloading tf_playwright_stealth-1.2.0-py3-none-any.whl (33 kB)
# Downloading fake_http_header-0.3.5-py3-none-any.whl (14 kB)
# Downloading tiktoken-0.11.0-cp313-cp313-win_amd64.whl (883 kB)
#    ---------------------------------------- 0.0/883.9 kB ? eta -:--:--
#    ----------------------------------- ---- 786.4/883.9 kB 4.9 MB/s eta 0:00:01
#    ---------------------------------------- 883.9/883.9 kB 3.8 MB/s  0:00:00
# Downloading trimesh-4.8.3-py3-none-any.whl (735 kB)
#    ---------------------------------------- 0.0/735.5 kB ? eta -:--:--
#    ---------------------------------------- 735.5/735.5 kB 3.5 MB/s  0:00:00
# Downloading typing_inspection-0.4.1-py3-none-any.whl (14 kB)
# Downloading zipp-3.23.0-py3-none-any.whl (10 kB)
# Downloading tokenizers-0.22.1-cp39-abi3-win_amd64.whl (2.7 MB)
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    ----------- ---------------------------- 0.8/2.7 MB 4.9 MB/s eta 0:00:01
#    --------------------------- ------------ 1.8/2.7 MB 4.6 MB/s eta 0:00:01
#    ---------------------------------------  2.6/2.7 MB 4.0 MB/s eta 0:00:01
#    ---------------------------------------- 2.7/2.7 MB 3.8 MB/s  0:00:00
# Downloading huggingface_hub-0.35.3-py3-none-any.whl (564 kB)
#    ---------------------------------------- 0.0/564.3 kB ? eta -:--:--
#    ---------------------------------------- 564.3/564.3 kB 3.0 MB/s  0:00:00
# Downloading fsspec-2025.9.0-py3-none-any.whl (199 kB)
# Downloading filelock-3.19.1-py3-none-any.whl (15 kB)
# Installing collected packages: snowballstemmer, brotli, zipp, xxhash, typing-inspection, trimesh, shapely, rtree, regex, rank-bm25, python-dotenv, pyee, pydantic-core, propcache, networkx, multidict, lxml, lark, jiter, hyperframe, humanize, hpack, greenlet, fsspec, frozenlist, filelock, fastuuid, fake-useragent, fake-http-header, distro, chardet, cffi, annotated-types, aiosqlite, aiohappyeyeballs, aiofiles, yarl, tiktoken, pydantic, playwright, patchright, nltk, importlib-metadata, huggingface-hub, h2, cryptography, click-log, aiosignal, tokenizers, tf-playwright-stealth, pyOpenSSL, openai, alphashape, aiohttp, litellm, crawl4ai
#
#    ----------------------------------------  0/56 [snowballstemmer]
#    ----------------------------------------  0/56 [snowballstemmer]
#    ----------------------------------------  0/56 [snowballstemmer]
#    ----------------------------------------  0/56 [snowballstemmer]
#    ----------------------------------------  0/56 [snowballstemmer]
#    ----------------------------------------  0/56 [snowballstemmer]
#    ----------------------------------------  0/56 [snowballstemmer]
#    ----------------------------------------  0/56 [snowballstemmer]
#    ----------------------------------------  0/56 [snowballstemmer]
#    ----------------------------------------  0/56 [snowballstemmer]
#    ----------------------------------------  0/56 [snowballstemmer]
#    ----------------------------------------  0/56 [snowballstemmer]
#    - --------------------------------------  2/56 [zipp]
#    - --------------------------------------  2/56 [zipp]
#    -- -------------------------------------  3/56 [xxhash]
#    -- -------------------------------------  4/56 [typing-inspection]
#    --- ------------------------------------  5/56 [trimesh]
#    --- ------------------------------------  5/56 [trimesh]
#    --- ------------------------------------  5/56 [trimesh]
#    --- ------------------------------------  5/56 [trimesh]
#    --- ------------------------------------  5/56 [trimesh]
#    --- ------------------------------------  5/56 [trimesh]
#    --- ------------------------------------  5/56 [trimesh]
#    --- ------------------------------------  5/56 [trimesh]
#    --- ------------------------------------  5/56 [trimesh]
#    --- ------------------------------------  5/56 [trimesh]
#    --- ------------------------------------  5/56 [trimesh]
#    --- ------------------------------------  5/56 [trimesh]
#    --- ------------------------------------  5/56 [trimesh]
#    --- ------------------------------------  5/56 [trimesh]
#    --- ------------------------------------  5/56 [trimesh]
#    --- ------------------------------------  5/56 [trimesh]
#    --- ------------------------------------  5/56 [trimesh]
#    --- ------------------------------------  5/56 [trimesh]
#    --- ------------------------------------  5/56 [trimesh]
#    --- ------------------------------------  5/56 [trimesh]
#    --- ------------------------------------  5/56 [trimesh]
#    --- ------------------------------------  5/56 [trimesh]
#    --- ------------------------------------  5/56 [trimesh]
#    --- ------------------------------------  5/56 [trimesh]
#    --- ------------------------------------  5/56 [trimesh]
#    --- ------------------------------------  5/56 [trimesh]
#    --- ------------------------------------  5/56 [trimesh]
#    --- ------------------------------------  5/56 [trimesh]
#    --- ------------------------------------  5/56 [trimesh]
#    --- ------------------------------------  5/56 [trimesh]
#    --- ------------------------------------  5/56 [trimesh]
#    --- ------------------------------------  5/56 [trimesh]
#    --- ------------------------------------  5/56 [trimesh]
#    --- ------------------------------------  5/56 [trimesh]
#    --- ------------------------------------  5/56 [trimesh]
#    --- ------------------------------------  5/56 [trimesh]
#    --- ------------------------------------  5/56 [trimesh]
#    ---- -----------------------------------  6/56 [shapely]
#    ---- -----------------------------------  6/56 [shapely]
#    ---- -----------------------------------  6/56 [shapely]
#    ---- -----------------------------------  6/56 [shapely]
#    ---- -----------------------------------  6/56 [shapely]
#    ---- -----------------------------------  6/56 [shapely]
#    ---- -----------------------------------  6/56 [shapely]
#    ---- -----------------------------------  6/56 [shapely]
#    ---- -----------------------------------  6/56 [shapely]
#    ---- -----------------------------------  6/56 [shapely]
#    ---- -----------------------------------  6/56 [shapely]
#    ---- -----------------------------------  6/56 [shapely]
#    ---- -----------------------------------  6/56 [shapely]
#    ---- -----------------------------------  6/56 [shapely]
#    ---- -----------------------------------  6/56 [shapely]
#    ---- -----------------------------------  6/56 [shapely]
#    ---- -----------------------------------  6/56 [shapely]
#    ---- -----------------------------------  6/56 [shapely]
#    ---- -----------------------------------  6/56 [shapely]
#    ---- -----------------------------------  6/56 [shapely]
#    ---- -----------------------------------  6/56 [shapely]
#    ---- -----------------------------------  6/56 [shapely]
#    ---- -----------------------------------  6/56 [shapely]
#    ---- -----------------------------------  6/56 [shapely]
#    ---- -----------------------------------  6/56 [shapely]
#    ---- -----------------------------------  6/56 [shapely]
#    ---- -----------------------------------  6/56 [shapely]
#    ---- -----------------------------------  6/56 [shapely]
#    ---- -----------------------------------  6/56 [shapely]
#    ---- -----------------------------------  6/56 [shapely]
#    ---- -----------------------------------  6/56 [shapely]
#    ---- -----------------------------------  6/56 [shapely]
#    ---- -----------------------------------  6/56 [shapely]
#    ---- -----------------------------------  6/56 [shapely]
#    ---- -----------------------------------  6/56 [shapely]
#    ---- -----------------------------------  6/56 [shapely]
#    ---- -----------------------------------  6/56 [shapely]
#    ----- ----------------------------------  7/56 [rtree]
#    ----- ----------------------------------  7/56 [rtree]
#    ----- ----------------------------------  7/56 [rtree]
#    ----- ----------------------------------  8/56 [regex]
#    ----- ----------------------------------  8/56 [regex]
#    ----- ----------------------------------  8/56 [regex]
#    ------- -------------------------------- 10/56 [python-dotenv]
#    ------- -------------------------------- 10/56 [python-dotenv]
#    ------- -------------------------------- 10/56 [python-dotenv]
#    ------- -------------------------------- 10/56 [python-dotenv]
#    ------- -------------------------------- 11/56 [pyee]
#    ------- -------------------------------- 11/56 [pyee]
#    ------- -------------------------------- 11/56 [pyee]
#    -------- ------------------------------- 12/56 [pydantic-core]
#    -------- ------------------------------- 12/56 [pydantic-core]
#    --------- ------------------------------ 13/56 [propcache]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 14/56 [networkx]
#    ---------- ----------------------------- 15/56 [multidict]
#    ---------- ----------------------------- 15/56 [multidict]
#    ----------- ---------------------------- 16/56 [lxml]
#    ----------- ---------------------------- 16/56 [lxml]
#    ----------- ---------------------------- 16/56 [lxml]
#    ----------- ---------------------------- 16/56 [lxml]
#    ----------- ---------------------------- 16/56 [lxml]
#    ----------- ---------------------------- 16/56 [lxml]
#    ----------- ---------------------------- 16/56 [lxml]
#    ----------- ---------------------------- 16/56 [lxml]
#    ----------- ---------------------------- 16/56 [lxml]
#    ----------- ---------------------------- 16/56 [lxml]
#    ----------- ---------------------------- 16/56 [lxml]
#    ------------ --------------------------- 17/56 [lark]
#    ------------ --------------------------- 17/56 [lark]
#    ------------ --------------------------- 17/56 [lark]
#    ------------ --------------------------- 17/56 [lark]
#    ------------ --------------------------- 17/56 [lark]
#    ------------ --------------------------- 17/56 [lark]
#    ------------ --------------------------- 17/56 [lark]
#    ------------ --------------------------- 17/56 [lark]
#    ------------ --------------------------- 17/56 [lark]
#    ------------ --------------------------- 17/56 [lark]
#    ------------ --------------------------- 17/56 [lark]
#    ------------- -------------------------- 19/56 [hyperframe]
#    ------------- -------------------------- 19/56 [hyperframe]
#    -------------- ------------------------- 20/56 [humanize]
#    -------------- ------------------------- 20/56 [humanize]
#    -------------- ------------------------- 20/56 [humanize]
#    --------------- ------------------------ 21/56 [hpack]
#    --------------- ------------------------ 21/56 [hpack]
#    --------------- ------------------------ 21/56 [hpack]
#    --------------- ------------------------ 22/56 [greenlet]
#    --------------- ------------------------ 22/56 [greenlet]
#    --------------- ------------------------ 22/56 [greenlet]
#    --------------- ------------------------ 22/56 [greenlet]
#    --------------- ------------------------ 22/56 [greenlet]
#    --------------- ------------------------ 22/56 [greenlet]
#    --------------- ------------------------ 22/56 [greenlet]
#    --------------- ------------------------ 22/56 [greenlet]
#    --------------- ------------------------ 22/56 [greenlet]
# ...
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    -------------------------------------- - 54/56 [litellm]
#    ---------------------------------------  55/56 [crawl4ai]
#    ---------------------------------------  55/56 [crawl4ai]
#    ---------------------------------------  55/56 [crawl4ai]
#    ---------------------------------------  55/56 [crawl4ai]
#    ---------------------------------------  55/56 [crawl4ai]
#    ---------------------------------------  55/56 [crawl4ai]
#    ---------------------------------------  55/56 [crawl4ai]
#    ---------------------------------------  55/56 [crawl4ai]
#    ---------------------------------------  55/56 [crawl4ai]
#    ---------------------------------------  55/56 [crawl4ai]
#    ---------------------------------------  55/56 [crawl4ai]
#    ---------------------------------------  55/56 [crawl4ai]
#    ---------------------------------------  55/56 [crawl4ai]
#    ---------------------------------------  55/56 [crawl4ai]
#    ---------------------------------------  55/56 [crawl4ai]
#    ---------------------------------------  55/56 [crawl4ai]
#    ---------------------------------------  55/56 [crawl4ai]
#    ---------------------------------------  55/56 [crawl4ai]
#    ---------------------------------------  55/56 [crawl4ai]
#    ---------------------------------------  55/56 [crawl4ai]
#    ---------------------------------------  55/56 [crawl4ai]
#    ---------------------------------------  55/56 [crawl4ai]
#    ---------------------------------------  55/56 [crawl4ai]
#    ---------------------------------------  55/56 [crawl4ai]
#    ---------------------------------------  55/56 [crawl4ai]
#    ---------------------------------------  55/56 [crawl4ai]
#    ---------------------------------------  55/56 [crawl4ai]
#    ---------------------------------------  55/56 [crawl4ai]
#    ---------------------------------------  55/56 [crawl4ai]
#    ---------------------------------------  55/56 [crawl4ai]
#    ---------------------------------------  55/56 [crawl4ai]
#    ---------------------------------------  55/56 [crawl4ai]
#    ---------------------------------------  55/56 [crawl4ai]
#    ---------------------------------------  55/56 [crawl4ai]
#    ---------------------------------------- 56/56 [crawl4ai]
#
# Successfully installed aiofiles-24.1.0 aiohappyeyeballs-2.6.1 aiohttp-3.12.15 aiosignal-1.4.0 aiosqlite-0.21.0 alphashape-1.3.1 annotated-types-0.7.0 brotli-1.1.0 cffi-2.0.0 chardet-5.2.0 click-log-0.4.0 crawl4ai-0.7.4 cryptography-46.0.1 distro-1.9.0 fake-http-header-0.3.5 fake-useragent-2.2.0 fastuuid-0.13.5 filelock-3.19.1 frozenlist-1.7.0 fsspec-2025.9.0 greenlet-3.2.4 h2-4.3.0 hpack-4.1.0 huggingface-hub-0.35.3 humanize-4.13.0 hyperframe-6.1.0 importlib-metadata-8.7.0 jiter-0.11.0 lark-1.3.0 litellm-1.77.5 lxml-5.4.0 multidict-6.6.4 networkx-3.5 nltk-3.9.1 openai-2.0.0 patchright-1.55.2 playwright-1.55.0 propcache-0.3.2 pyOpenSSL-25.3.0 pydantic-2.11.9 pydantic-core-2.33.2 pyee-13.0.0 python-dotenv-1.1.1 rank-bm25-0.2.2 regex-2025.9.18 rtree-1.4.1 shapely-2.1.2 snowballstemmer-2.2.0 tf-playwright-stealth-1.2.0 tiktoken-0.11.0 tokenizers-0.22.1 trimesh-4.8.3 typing-inspection-0.4.1 xxhash-3.5.0 yarl-1.20.1 zipp-3.23.0

# %%
import asyncio
from crawl4ai import AsyncWebCrawler , CrawlerRunConfig
from crawl4ai.deep_crawling import BFSDeepCrawlStrategy
from crawl4ai.content_scraping_strategy import LXMLWebScrapingStrategy

# %%
async def main():
    #Configure the 2-level deep crawl
    config = CrawlerRunConfig(
        deep_crawl_strategy = BFSDeepCrawlStrategy(max_depth=2,include_external=False),
        scraping_strategy = LXMLWebScrapingStrategy(),
        verbose=True
    )

    async with AsyncWebCrawler() as crawler:
        results = await crawler.arun("https://www.wikipedia.org", config=config)
        print(f"Crawled {len(results)} pages in total")
        for result in results[:3]:
            print(f"URL: {result.url}")
            print(f"Depth: {result.metadata.get('depth',0)}")

# %%
if __name__ == "__main__":
    asyncio.run(main())
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[4], line 3
#       1 # if __name__ == "__main__":
#       2 #     asyncio.run(main())
# ----> 3 await main()
#
# Cell In[2], line 9, in main()
#       1 async def main():
#       2     #Configure the 2-level deep crawl
#       3     config = CrawlerRunConfig(
#       4         deep_crawl_strategy = BFSDeepCrawlStrategy(max_depth=2,include_external=False),
#       5         scraping_strategy = LXMLWebScrapingStrategy(),
#       6         verbose=True
#       7     )
# ----> 9     async with AsyncWebCrawler() as crawler:
#      10         results = await crawler.arun("https://www.wikipedia.org", config=config)
#      11         print(f"Crawled {len(results)} pages in total")
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\crawl4ai\async_webcrawler.py:194, in AsyncWebCrawler.__aenter__(self)
#     193 async def __aenter__(self):
# --> 194     return await self.start()
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\crawl4ai\async_webcrawler.py:177, in AsyncWebCrawler.start(self)
#     170 async def start(self):
#     171     """
#     172     Start the crawler explicitly without using context manager.
#     173     This is equivalent to using 'async with' but gives more control over the lifecycle.
#     174     Returns:
#     175         AsyncWebCrawler: The initialized crawler instance
#     176     """
# --> 177     await self.crawler_strategy.__aenter__()
#     178     self.logger.info(f"Crawl4AI {crawl4ai_version}", tag="INIT")
#     179     self.ready = True
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\crawl4ai\async_crawler_strategy.py:119, in AsyncPlaywrightCrawlerStrategy.__aenter__(self)
#     118 async def __aenter__(self):
# --> 119     await self.start()
#     120     return self
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\crawl4ai\async_crawler_strategy.py:129, in AsyncPlaywrightCrawlerStrategy.start(self)
#     125 async def start(self):
#     126     """
#     127     Start the browser and initialize the browser manager.
#     128     """
# --> 129     await self.browser_manager.start()
#     130     await self.execute_hook(
#     131         "on_browser_created",
#     132         self.browser_manager.browser,
#     133         context=self.browser_manager.default_context,
#     134     )
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\crawl4ai\browser_manager.py:661, in BrowserManager.start(self)
#     659     self.playwright = await self._stealth_cm.__aenter__()
#     660 else:
# --> 661     self.playwright = await async_playwright().start()
#     663 if self.config.cdp_url or self.config.use_managed_browser:
#     664     self.config.use_managed_browser = True
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\playwright\async_api\_context_manager.py:51, in PlaywrightContextManager.start(self)
#      50 async def start(self) -> AsyncPlaywright:
# ---> 51     return await self.__aenter__()
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\playwright\async_api\_context_manager.py:46, in PlaywrightContextManager.__aenter__(self)
#      44 if not playwright_future.done():
#      45     playwright_future.cancel()
# ---> 46 playwright = AsyncPlaywright(next(iter(done)).result())
#      47 playwright.stop = self.__aexit__  # type: ignore
#      48 return playwright
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\playwright\_impl\_transport.py:120, in PipeTransport.connect(self)
#     117         startupinfo.wShowWindow = subprocess.SW_HIDE
#     119     executable_path, entrypoint_path = compute_driver_executable()
# --> 120     self._proc = await asyncio.create_subprocess_exec(
#     121         executable_path,
#     122         entrypoint_path,
#     123         "run-driver",
#     124         stdin=asyncio.subprocess.PIPE,
#     125         stdout=asyncio.subprocess.PIPE,
#     126         stderr=_get_stderr_fileno(),
#     127         limit=32768,
#     128         env=env,
#     129         startupinfo=startupinfo,
#     130     )
#     131 except Exception as exc:
#     132     self.on_error_future.set_exception(exc)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\asyncio\subprocess.py:224, in create_subprocess_exec(program, stdin, stdout, stderr, limit, *args, **kwds)
#     221 loop = events.get_running_loop()
#     222 protocol_factory = lambda: SubprocessStreamProtocol(limit=limit,
#     223                                                     loop=loop)
# --> 224 transport, protocol = await loop.subprocess_exec(
#     225     protocol_factory,
#     226     program, *args,
#     227     stdin=stdin, stdout=stdout,
#     228     stderr=stderr, **kwds)
#     229 return Process(transport, protocol, loop)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\asyncio\base_events.py:1788, in BaseEventLoop.subprocess_exec(self, protocol_factory, program, stdin, stdout, stderr, universal_newlines, shell, bufsize, encoding, errors, text, *args, **kwargs)
#    1786     debug_log = f'execute program {program!r}'
#    1787     self._log_subprocess(debug_log, stdin, stdout, stderr)
# -> 1788 transport = await self._make_subprocess_transport(
#    1789     protocol, popen_args, False, stdin, stdout, stderr,
#    1790     bufsize, **kwargs)
#    1791 if self._debug and debug_log is not None:
#    1792     logger.info('%s: %r', debug_log, transport)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\asyncio\base_events.py:533, in BaseEventLoop._make_subprocess_transport(self, protocol, args, shell, stdin, stdout, stderr, bufsize, extra, **kwargs)
#     529 async def _make_subprocess_transport(self, protocol, args, shell,
#     530                                      stdin, stdout, stderr, bufsize,
#     531                                      extra=None, **kwargs):
#     532     """Create subprocess transport."""
# --> 533     raise NotImplementedError
#
# NotImplementedError:
